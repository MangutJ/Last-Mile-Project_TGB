# %% [markdown]
# # NETFLUX Movie Recommendation Engine

# %%
import pandas as pd
import numpy as np
import os
import zipfile as ZipFile
import gzip
from functools import reduce 
# set pandas dataframe global options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Ingesting Data

# %%
def read_file():
    """ Checks if the given directory exists. Creates the directory if it does not exist.

    Reads the gzipped files
    Raises:
        Exception: Any error message
    """
    directory = r"C:\Work\Last-Mile-Project_TGB\Files"
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except Exception as e:
        print('ensure_directory_exist: ' + re)
    for filename in os.listdir(directory):
        file_extension = filename.split('.')[-1]
        if file_extension == 'gz':
            k = gzip.open(os.path.join(directory, filename), 'r')
            with k as data:
                i = 0
                for line in data:
                    print(line)
                    i +=1
                    if i==10:
                        print(filename + 'read successfully')
                        break
                    
        else:
            continue

# %%
read_file()
# Out:
# b'titleId\tordering\ttitle\tregion\tlanguage\ttypes\tattributes\tisOriginalTitle\n'
# b'tt0000001\t1\t\xd0\x9a\xd0\xb0\xd1\x80\xd0\xbc\xd0\xb5\xd0\xbd\xd1\x81\xd1\x96\xd1\x82\xd0\xb0\tUA\t\\N\timdbDisplay\t\\N\t0\n'
# b'tt0000001\t2\tCarmencita\tDE\t\\N\t\\N\tliteral title\t0\n'
# b'tt0000001\t3\tCarmencita - spanyol t\xc3\xa1nc\tHU\t\\N\timdbDisplay\t\\N\t0\n'
# b'tt0000001\t4\t\xce\x9a\xce\xb1\xcf\x81\xce\xbc\xce\xb5\xce\xbd\xcf\x83\xce\xaf\xcf\x84\xce\xb1\tGR\t\\N\timdbDisplay\t\\N\t0\n'
# b'tt0000001\t5\t\xd0\x9a\xd0\xb0\xd1\x80\xd0\xbc\xd0\xb5\xd0\xbd\xd1\x81\xd0\xb8\xd1\x82\xd0\xb0\tRU\t\\N\timdbDisplay\t\\N\t0\n'
# b'tt0000001\t6\tCarmencita\tUS\t\\N\timdbDisplay\t\\N\t0\n'
# b'tt0000001\t7\tCarmencita\t\\N\t\\N\toriginal\t\\N\t1\n'
# b'tt0000001\t8\t\xe3\x82\xab\xe3\x83\xab\xe3\x83\xa1\xe3\x83\xb3\xe3\x83\x81\xe3\x83\xbc\xe3\x82\xbf\tJP\tja\timdbDisplay\t\\N\t0\n'
# b'tt0000002\t1\tLe clown et ses chiens\t\\N\t\\N\toriginal\t\\N\t1\n'
# title.akas.tsv.gzread successfully
# b'tconst\ttitleType\tprimaryTitle\toriginalTitle\tisAdult\tstartYear\tendYear\truntimeMinutes\tgenres\n'
# b'tt0000001\tshort\tCarmencita\tCarmencita\t0\t1894\t\\N\t1\tDocumentary,Short\n'
# b'tt0000002\tshort\tLe clown et ses chiens\tLe clown et ses chiens\t0\t1892\t\\N\t5\tAnimation,Short\n'
# b'tt0000003\tshort\tPauvre Pierrot\tPauvre Pierrot\t0\t1892\t\\N\t4\tAnimation,Comedy,Romance\n'
# b'tt0000004\tshort\tUn bon bock\tUn bon bock\t0\t1892\t\\N\t12\tAnimation,Short\n'
# b'tt0000005\tshort\tBlacksmith Scene\tBlacksmith Scene\t0\t1893\t\\N\t1\tComedy,Short\n'
# b'tt0000006\tshort\tChinese Opium Den\tChinese Opium Den\t0\t1894\t\\N\t1\tShort\n'
# b'tt0000007\tshort\tCorbett and Courtney Before the Kinetograph\tCorbett and Courtney Before the Kinetograph\t0\t1894\t\\N\t1\tShort,Sport\n'
# b'tt0000008\tshort\tEdison Kinetoscopic Record of a Sneeze\tEdison Kinetoscopic Record of a Sneeze\t0\t1894\t\\N\t1\tDocumentary,Short\n'
# b'tt0000009\tshort\tMiss Jerry\tMiss Jerry\t0\t1894\t\\N\t40\tRomance,Short\n'
# title.basics.tsv.gzread successfully
# b'tconst\tdirectors\twriters\n'
# b'tt0000001\tnm0005690\t\\N\n'
# b'tt0000002\tnm0721526\t\\N\n'
# b'tt0000003\tnm0721526\t\\N\n'
# b'tt0000004\tnm0721526\t\\N\n'
# b'tt0000005\tnm0005690\t\\N\n'
# b'tt0000006\tnm0005690\t\\N\n'
# b'tt0000007\tnm0005690,nm0374658\t\\N\n'
# b'tt0000008\tnm0005690\t\\N\n'
# b'tt0000009\tnm0085156\tnm0085156\n'
# title.crew.tsv.gzread successfully
# b'tconst\taverageRating\tnumVotes\n'
# b'tt0000001\t5.7\t1828\n'
# b'tt0000002\t6.0\t233\n'
# b'tt0000003\t6.5\t1581\n'
# b'tt0000004\t6.1\t151\n'
# b'tt0000005\t6.2\t2406\n'
# b'tt0000006\t5.2\t157\n'
# b'tt0000007\t5.4\t751\n'
# b'tt0000008\t5.5\t1979\n'
# b'tt0000009\t5.9\t190\n'
# title.ratings.tsv.gzread successfully

# %%
def return_dataframe(filename, directory):
    """ Reads a file into memory and returns a dataframe.

    Args:
        filename (str): name of file to read.
        path (str, optional): path to the file to read. Defaults to None.

    Raises:
        ValueError: File type is not supported.
        ValueError: Invalid file name
        Exception: Any other error message

    Returns:
        [DataFrame]: The file read into memory as a DataFrame.
    """
    directory = r"C:\Work\Last-Mile-Project_TGB\Files"
    df = pd.DataFrame()
    if len(filename) > 1:
        try:
            if not directory:
                directory = 'Input'

            file_type = filename.split('.')[2]
            long_file_name = os.path.join(directory, filename) 
            if file_type == 'tsv':
                df = pd.read_csv(long_file_name, sep='\t', low_memory=False)
            elif file_type in ['xls', 'xlsx']:
                df = pd.read_excel(long_file_name)
            else:
                raise ValueError(f"{file_type} File type is not supported")
        except Exception as e:
            print('read_file: ' + repr(e))

    else:
        raise ValueError("Invalid File Name")

    return df

# %%
Ratings = return_dataframe(filename= 'title.ratings.tsv.gz', directory= "C:\Work\Last-Mile-Project_TGB\Files")

# %%
Ratings.shape
# Out:
# (1194630, 3)

# %%
Ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1828
# 1  tt0000002            6.0       233
# 2  tt0000003            6.5      1581
# 3  tt0000004            6.1       151
# 4  tt0000005            6.2      2406

# %%
Crew = return_dataframe(filename= 'title.crew.tsv.gz', directory= "C:\Work\Last-Mile-Project_TGB\Files")

# %%
Crew.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %%
Basics = return_dataframe(filename= 'title.basics.tsv.gz', directory= "C:\Work\Last-Mile-Project_TGB\Files")

# %%
Basics.shape
# Out:
# (8353147, 9)

# %%
Basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
#Akas = return_dataframe(filename= 'title.akas.tsv.gz', directory= "C:\Work\Last-Mile-Project_TGB\Files" )

# %%
#Akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
#Akas.shape#rename(columns= {'titleId':'tconst'})
# Out:
# (29436752, 8)

# %%
Crew.shape
# Out:
# (8353147, 3)

# %%
#Akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
#Akas.columns = ['tconst','ordering','title','region','language','types','attributes','isOriginalTitle']

# %%
#Akas.head()
# Out:
#       tconst  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
#Akas.shape

# %%
 #Couldn't add the Akas dataframe due to the filesize which was too large for my machine to handle

# %%
## throw different datafranes into a list
data_frames = [Ratings, Crew, Basics]

IMDB = reduce(lambda left,right: pd.merge(left,right, on= ['tconst'], how='outer'), data_frames)

# %%
IMDB_data = IMDB.sample(n=10000)

# %%
IMDB_data.tail()
# Out:
#              tconst  averageRating  numVotes  directors  \
# 6155582   tt4589834            NaN       NaN         \N
# 1030903   tt6113642            8.6    5130.0  nm0000399
# 2881092  tt12233422            NaN       NaN  nm0134018
# 4220899  tt14753752            NaN       NaN         \N
# 7287780   tt7449048            NaN       NaN         \N
#
#                                                    writers  titleType  \
# 6155582                                                 \N  tvEpisode
# 1030903  nm0671856,nm0235123,nm0647833,nm5616730,nm1964043  tvEpisode
# 2881092                                nm0028070,nm0523545  tvEpisode
# 4220899                                                 \N  tvEpisode
# 7287780                                                 \N  tvEpisode
#
#                          primaryTitle                 originalTitle isAdult  \
# 6155582                 Episode #1.70                 Episode #1.70       0
# 1030903                  Episode #1.9                  Episode #1.9       0
# 2881092      Quiero pedirte algo Mamá      Quiero pedirte algo Mamá       0
# 4220899                 Episode #2.16                 Episode #2.16       0
# 7287780  Jay Leno's Extreme Roadsters  Jay Leno's Extreme Roadsters       0
#
#         startYear endYear runtimeMinutes                genres
# 6155582        \N      \N             \N               Fantasy
# 1030903      2017      \N             48  Crime,Drama,Thriller
# 2881092      1993      \N             \N  Crime,Drama,Thriller
# 4220899      2015      \N             \N            Reality-TV
# 7287780      2008      \N             20   Documentary,History

# %%
IMDB_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 6118729 to 7287780
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          10000 non-null  object
#  1   averageRating   1373 non-null   float64
#  2   numVotes        1373 non-null   float64
#  3   directors       10000 non-null  object
#  4   writers         10000 non-null  object
#  5   titleType       10000 non-null  object
#  6   primaryTitle    10000 non-null  object
#  7   originalTitle   10000 non-null  object
#  8   isAdult         10000 non-null  object
#  9   startYear       10000 non-null  object
#  10  endYear         10000 non-null  object
#  11  runtimeMinutes  10000 non-null  object
#  12  genres          10000 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
IMDB_data.describe()
# Out:
#        averageRating       numVotes
# count    1373.000000    1373.000000
# mean        6.882302    1719.927167
# std         1.414765   27327.860115
# min         1.000000       5.000000
# 25%         6.200000      11.000000
# 50%         7.100000      23.000000
# 75%         7.800000      89.000000
# max        10.000000  747416.000000

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
## Helper fuctions to be used when needed

def get_title_from_index(tconst):
    return IMDB_data[IMDB_data.tconst == tconst]["originalTitle"]

def get_index_from_title(originalTitle):
    return IMDB_data[IMDB_data.originalTitle == originalTitle]["tconst"]

# %%
##select features

features = ['directors','writers','titleType','originalTitle','genres']

for feature in features:
    IMDB_data[feature] = IMDB_data[feature].astype(str)
    IMDB_data[feature] = IMDB_data[feature].fillna('')

# %%
IMDB_data[feature].tail()
# Out:
# 6155582                 Fantasy
# 1030903    Crime,Drama,Thriller
# 2881092    Crime,Drama,Thriller
# 4220899              Reality-TV
# 7287780     Documentary,History
# Name: genres, dtype: object

# %%
IMDB_data[feature].shape
# Out:
# (10000,)

# %%
##create a column in dataframe which combines all selected features

def combined_features(row):
    return row['directors'] +" "+row['writers']+" "+row['titleType']+" "+row['originalTitle']+" "+row['genres']
IMDB_data["combined_features"] = IMDB_data.apply(combined_features,axis=1)

i=0
for data in IMDB_data["combined_features"]:
    print(data)
    i=+1
    if i>5:
        break
    else:
        continue
# Out:
# \N nm3187496,nm1869070,nm1764866,nm2077444,nm6757155,nm2908884,nm1515533,nm2588968,nm2122012 tvEpisode Episode #1.158 Comedy,Drama,Romance
# nm1070598 nm2717818,nm1834305 tvEpisode Das Große Finale Game-Show,Reality-TV
# nm3514859 \N tvEpisode Episode #31.15 Game-Show
# nm6533812 nm6533812 short Dafatan Drama,Short
# \N \N tvEpisode Episode #1.774 News
# nm0287835 \N short Thrills of Music: Ina Ray Hutton and Orchestra Music,Short
# \N nm0032643,nm2194186,nm1293423 tvEpisode Episode #1.700 Talk-Show
# nm0219985,nm1729691 nm1729691,nm0001769 tvEpisode 9.12.01: The Day After Comedy,Talk-Show
# nm2386413,nm7553545 \N tvEpisode Miffy at the Library Animation,Family
# nm5053760 nm5054027,nm5068906 tvEpisode Episode #1.83 Drama
# nm1876309 nm1876309 tvEpisode Episode #1.168 Drama
# \N \N tvEpisode Episode #1.7633 News
# \N \N tvEpisode Episode #1.5 Action,Drama,Fantasy
# nm8850148,nm8850133 nm8850135,nm9041355 tvEpisode Episode #1.326 Comedy,Family
# \N \N tvEpisode Episode dated 13 October 2017 \N
# \N \N tvEpisode Episode #1.72 Talk-Show
# nm3361980,nm2401362 nm2404427,nm4309802,nm0646248 tvEpisode Episode #2.48 Comedy,Drama,Fantasy
# \N \N tvEpisode Female-Centric HE-MAN? Jar Jar SUPERMAN? Star Trek TROUBLE! YouTube and FREE SPEECH Talk-Show
# \N nm5327789 tvEpisode Cruz de Guia Documentary
# nm5514626,nm5519375 nm1689260,nm5730456 tvEpisode Episode #1.16 Action,Crime,Drama
# \N \N tvEpisode Precious Digits Footjob and Big Booty Tease Adult
# nm0958801 nm0073053,nm0207401,nm0575804,nm0665993,nm0958801 movie La ragazza con la valigia Drama,Romance
# nm0180458 nm0724255 tvEpisode Snowstorm in the Jungle Documentary
# \N \N tvEpisode Everything Wrong With Zack Snyder's Justice League Part 1 In 22 Minutes Or Less Comedy
# \N nm0914844 tvEpisode Episode #1.761 Drama,Romance
# \N \N tvEpisode Episode #25.30 \N
# \N \N videoGame Zeppelin: Giants of the Sky History
# \N \N tvEpisode Carlotta News
# nm2554911,nm0665889 nm0001122,nm1968686 tvEpisode Episode #10.146 Comedy,Talk-Show
# \N \N tvEpisode Episode dated 12 February 2004 \N
# \N nm0128851,nm0760848 tvEpisode Episode #1.835 Family
# nm5716506 nm5716506 movie Apocalyptic Horror Horror
# nm12020680 nm2190786 tvEpisode Episode #1.164 Drama,Romance
# \N \N tvEpisode Episode #1.34 Fantasy,Horror,Mystery
# nm8457691,nm0954698 nm7160298 tvEpisode Episode #1.829 Animation,Family
# nm0238703 nm0122407 tvEpisode James Reality-TV,Sport
# nm0129638 nm0406585,nm0957995 movie Gli spettri Drama
# nm0264591 nm0264591 short Cowboy Pluck Short,Western
# nm0923571 nm0567228 tvEpisode Artful Dodgers Crime,Drama,Thriller
# \N \N tvEpisode Episode #5.16 Action,Sport
# nm8850133,nm12621560 nm8850135,nm12621559 tvEpisode Episode #1.1138 Comedy,Family
# \N \N video Dream Evil: Children of the Night Music,Short
# nm1482625 nm1482625,nm1501881 tvSeries Herman Jones Horror,Mystery,Thriller
# nm4423362 nm9953586,nm9953587 tvEpisode Episode #1.113 Comedy,Drama,Family
# nm1757669 nm0779670,nm0862680,nm12397551 tvEpisode The Great Flight Family,Sci-Fi
# \N \N tvEpisode Episode dated 6 August 2021 Talk-Show
# \N \N tvEpisode Mimicry of Mr. Lakhan Reality-TV
# \N \N video Brazzers Goes Black 2: The MILF Edition Adult
# nm1388009 \N tvEpisode At Christmas Comedy,Game-Show
# \N nm4842962,nm8303890 movie Sector 9 Drama,Fantasy,Horror
# \N \N tvEpisode The Long Hot Supper Drama
# nm1659900 nm0007657,nm2244391,nm1461377,nm1659900,nm1656256,nm1654219 tvEpisode Érase un anillo Comedy,Romance
# \N \N movie 9th Class C/o Eleshwaram Romance
# nm1628845 nm1628845 short The Promise? Short,Thriller
# \N \N movie Ntou apo pantou \N
# nm0475430,nm0235465 nm1879108,nm1876156 tvEpisode Episode #11.146 Crime,Reality-TV
# nm3712339 \N short Los tres hermanos Drama,Short
# nm1083609 nm0095876 tvEpisode Episode #13.248 Drama
# \N \N tvEpisode Wer gewinnt heute? - 17.06.1972 Family
# nm5053760 nm5054027,nm5068906 tvEpisode Episode #1.341 Drama
# nm0269502 nm0352709,nm1752032,nm0437032 tvEpisode Love and War Crime,Drama,Mystery
# \N \N tvEpisode Episode #1.8 Drama
# \N \N movie Sporting Gijón vs Real Madrid Action
# nm1206693 nm0587043,nm6345135,nm3677049,nm6348599,nm2240513,nm3346409,nm1702396,nm3355350,nm5920000,nm3625432,nm0266422,nm6847304,nm4433674,nm8270220,nm5668945,nm3688724,nm3918123,nm3618100,nm5369064,nm5194546 tvEpisode Katie Holmes/Andrew Rannells/Zac Brown Band Comedy,Music,Talk-Show
# nm5360857 \N tvEpisode Wormwood Scrubs History
# \N \N tvEpisode Episode #1.3409 News
# \N \N tvEpisode Chapter 3 - Operators Family
# \N \N tvEpisode Cuomo and de Blasio Lockdown Regimes Smacked by Judge News
# \N \N tvEpisode The Corrs - Planet Rock Profiles Music,Talk-Show
# \N \N tvEpisode Go the Distance from Hercules Comedy,Fantasy,Music
# nm0761055 nm1196267 tvEpisode Episode #1.113 Action,Adventure,Drama
# \N \N tvEpisode Rock Wives Biography,Documentary
# nm9279397 nm9279397 short Babyphone Mystery,Short
# nm0141225 \N tvEpisode Episode #15.135 Family,Game-Show
# nm5319964 \N tvEpisode Episode #1.186 Drama
# \N \N tvEpisode Episode #2.3 Comedy,Crime,Family
# \N nm3891050 movie The Code Action
# nm2165066,nm1085270 nm0554962,nm0599413 tvEpisode Episode #1.7 Crime,Drama,Fantasy
# nm1041120 nm1080629,nm0133144,nm0286091,nm0535500,nm1102269,nm1720904,nm0883283 tvEpisode Episode #4.26 Comedy,Drama,Family
# \N \N tvEpisode Mohamed Ali: icône d'une époque/Les années 60: Une longue marche pour la liberté Documentary,News
# \N \N tvMovie Heavenly Bodies Documentary
# nm10564978 nm0474861,nm1802260 tvEpisode Episode #1.311 \N
# \N \N tvEpisode Episode #1.363 Drama
# nm1497006 \N movie Mission Possible Documentary
# \N \N tvEpisode Episode #7.27 News,Talk-Show
# \N \N tvEpisode Miami Shootout Crime
# nm3731171 nm3731171,nm4772058 tvEpisode Episode #1.3 Comedy,Family
# \N \N tvEpisode Episode #16.3 \N
# \N \N tvEpisode Episode dated 8 December 2008 Crime,Reality-TV
# \N nm2873822 short A Week Goes By... Drama,Short
# nm0867247 \N movie Caring \N
# \N \N tvEpisode Episode #2.1 Comedy,Family,Music
# \N nm1024604,nm1086084 movie Getting Out \N
# nm6180911 nm0847634 tvMovie Kabuka 0!! Shoukenman no atsui natsu Drama
# \N \N tvEpisode Episode #12.21 Game-Show,Reality-TV
# \N \N tvEpisode Whole Chicken in a Can Comedy,Reality-TV,Talk-Show
# \N \N tvEpisode Game Night #3: Happy New Year! Talk-Show
# nm0563585 nm0563585 movie A Hero for Daisy Documentary
# nm0328837 nm0047143,nm0323218 tvEpisode Amo, Amas, Amat Comedy,Drama
# nm0180892 nm0180892 short Nothing in the Dark Horror,Short
# \N \N tvEpisode Zelda Twilight Princess - Part 54: Very Cool Boss Fight Comedy
# nm2964926 \N video Melissa Bathory: Pearl Music,Short
# nm0443519 \N tvEpisode Stephen Jay Gould Documentary
# nm1389277 nm2154398,nm2057891 tvEpisode Kryfoi desmoi Horror,Mystery
# nm0918465 nm0609600,nm0744793,nm0166256,nm0568490,nm0575293,nm0615780,nm0789624 tvEpisode Hercules and the Arabian Night Action,Adventure,Animation
# nm4371943,nm8994244 nm8374592,nm6427250,nm3996936 tvEpisode Episode #1.102 Drama
# \N \N tvEpisode Episode #2.37 Game-Show
# nm11504324 \N tvEpisode Episode #1.299 Drama
# nm0022750 \N tvEpisode Episode #2.59 Comedy
# \N \N tvEpisode Episode #12.61 Comedy,Family,Music
# nm0326950,nm1042011,nm0190483 nm1158335,nm1039584,nm1158744,nm0251110,nm0350844,nm1159741,nm1161915,nm0733876,nm1041589 tvEpisode Episode #1.124 \N
# nm0739298 nm0739298 movie El juego del adulterio Drama,Horror,Mystery
# nm1374883 nm9653981,nm1374448,nm1374822 tvEpisode Dumb Cocco Animation,Comedy,Western
# nm0243455,nm0308948,nm0626446 nm0106039,nm0140515,nm0306035,nm1532678 tvEpisode Intento desesperado Drama,Romance
# \N \N short Jellies & Other Ocean Drifters Short
# \N \N tvEpisode Episode dated 20 April 2013 Talk-Show
# nm3533543 nm3533543 movie Mezi námi práteli Comedy,Drama
# \N \N tvEpisode Episode #1.5 Comedy,Family,Game-Show
# \N \N tvEpisode The Crack of the Whip Drama,Fantasy
# \N \N tvEpisode Celebration and Chaos Reality-TV
# \N nm1939332,nm0160988 movie Deadtown Crime
# \N nm11684942 tvEpisode Episode #1.6 Drama,History,Romance
# \N nm0352270 tvEpisode Episode #1.17 Drama,Mystery
# \N \N tvEpisode Who Left Ms Dark Bound and Gagged in the Closet! Adult
# nm0195537,nm0480831,nm0619599,nm3203201 nm0844327,nm1804726,nm2808738,nm0034201,nm0182911,nm1570786,nm7802394 tvEpisode Épisode 424 Comedy,Crime,Drama
# nm0113512 nm0111156,nm0338355,nm0459679,nm0972418,nm1337895,nm3485259,nm1302282,nm1656336 tvEpisode Episode #2.117 Comedy,Music,Talk-Show
# nm0605600 nm0229890,nm0229908,nm0711626,nm0846520 tvEpisode Episode #1.1848 Drama,Romance
# nm0942941 nm0365510 tvEpisode Episode #1.12 Adventure,Family
# \N \N tvEpisode Episode dated 28 September 2015 News
# \N \N tvEpisode The White Room Game-Show,Reality-TV
# nm9634426 nm9927978 tvMovie Freud 2.0 - Il destino di un pensiero che ha cambiato il mondo Documentary
# \N \N tvEpisode Episode dated 4 March 2021 \N
# nm4035037 \N short Hyper-Reality Sci-Fi,Short
# \N nm7284849 tvEpisode Episode #1.76 \N
# \N \N tvEpisode Will a Black Woman be Our Next Vice President? (Val Demings) Talk-Show
# nm10038123 nm10038123 short Good As New Comedy,Short
# \N nm11227046,nm1422099 tvEpisode Episode #1.941 Drama
# nm0854104,nm2355477,nm4387984,nm3861808 nm7247103,nm2077444,nm1863397,nm2037442,nm8054539,nm4675917,nm1757944,nm4264151,nm8126751,nm3086898 tvEpisode Episode #1.235 Drama
# \N \N tvEpisode Episode #1.1949 News
# nm0816879 nm5339228,nm0816879 movie Rewind Drama
# \N \N tvEpisode Time Travel Animation,News
# nm2650810 \N tvEpisode Kaimaktsalan, odigontas sta hionia Documentary
# \N \N tvEpisode Episode #4.173 News,Talk-Show
# nm9785742 \N tvEpisode Episode #1.64 Drama
# \N \N tvMovie The Housekeeper Peeped! \N
# \N \N tvEpisode Sanyukta's Engagement Is Fixed Action,Drama,Thriller
# nm0234669 nm0445916,nm0589131 tvEpisode The Invader Comedy
# nm11482245 nm11600639,nm11600640,nm11598179 tvEpisode Episode #1.334 Drama
# \N \N tvEpisode Can I Get a Witness? An Intimate Conversation with Ann Nesby Talk-Show
# nm12440838,nm11886531 \N video Amar Sehmbi: Chief Guest Music,Short
# nm1931625,nm0753826,nm0785498 nm0013381,nm1656304,nm0739310,nm0739445,nm1082971 tvEpisode Episode #1.92 Drama
# \N \N tvEpisode México Adventure
# nm0320113 nm0320113 movie Coming Apart Drama
# \N \N video Juicy Holes Adult
# nm0395303 nm0395303,nm3703785 tvEpisode Ep. 14: Lo Pan's Bachelor Party (Minutes 65-70) Talk-Show
# nm9891925 nm10826863,nm10826864 tvEpisode Episode #1.973 Comedy
# \N \N tvEpisode Nataly Gold Gangbang SZ1858 Adult
# nm1405002 \N tvEpisode Episode #2.8 Drama
# \N \N tvEpisode 9 June 2021: Late Bulletin News
# nm5262331,nm4596616 nm7141603,nm7141604 tvEpisode Episode #1.195 Comedy,Drama
# \N nm1314316 tvEpisode Episode dated 21 August 2007 News
# \N \N tvEpisode Choke Out Tie Zippered, Caned, Tortured W/Brutal Orgasms, Pulled to Toes & Crotch Roped! INTENSE! Adult
# \N \N tvEpisode Episode dated 18 January 2010 Talk-Show
# \N \N tvEpisode Fun with Sparks Family
# \N \N tvEpisode Episode #2.28 Talk-Show
# nm0870699 nm0877425,nm0877901,nm0106373,nm0628167,nm1000265,nm1124309 tvEpisode (I Can't Get No) Satisfaction Comedy,Drama,Romance
# nm0629999 nm0291128,nm0548529,nm0909408 tvEpisode To a Moment of Triumph Drama
# \N \N tvEpisode Ben O'Rourke Documentary,Sport
# \N \N tvEpisode Episode dated 6 May 2020 \N
# nm1883879 nm1883879,nm0211847 movie Le smorfie di Pulcinella \N
# \N \N tvEpisode Der Fall Horror
# nm0918089 nm0503600,nm0817065 video U.S. Seals Action,Thriller
# nm0594001,nm0579489 nm1410073,nm2096841,nm6114909 tvEpisode Episode #1.51 Action,Romance
# \N \N tvEpisode Flughafenausbau - Dicke Luft im Erdinger Moos Documentary,Talk-Show
# \N \N tvEpisode Episode dated 17 May 2007 News
# \N \N short London Fire Call Documentary,Short
# nm8956963 nm8956963 short Insomnia Fantasy,Short
# \N \N tvEpisode Episode dated 1 November 1948 Comedy,Family,Music
# \N nm1314316 tvEpisode Episode dated 1 August 2012 News
# \N \N tvEpisode Episode #1.21 Drama,Romance
# \N \N tvEpisode Hot Babe at the Gate - Striptease is Her Key Adult
# \N \N tvEpisode Episode #1.601 Drama
# nm1449035 \N tvEpisode Blood, Sweat and No Tears \N
# nm4721080 \N tvEpisode Emily Reality-TV
# nm8781484 nm8781484 short Samir, Sheikh El Chabeb Comedy,Crime,Drama
# \N \N videoGame Parufe: Shokora Second Brew Adult,Romance
# \N \N tvEpisode Episode #3.4 Reality-TV
# nm4045838 nm4045838 video Desperado: Ölelj át (feat. Cozombolis) Music,Short
# nm5556873 nm5556777,nm5556873 short Trick or Tweet Comedy,Horror,Short
# \N \N tvEpisode Style-City Music, J.Hill, Naturaul Colour, Young Balli, Yuri Birilov, Phor, Harlem World, 20 Twen Music
# nm3462001 nm3702875 tvMovie Fabulous High Comedy,Drama
# \N nm0452929 tvEpisode Episode #6.112 Comedy,Talk-Show
# \N \N tvEpisode Episode dated 28 April 2016 News
# nm9287440,nm5460792 nm2903076,nm0430816 tvEpisode Episode #1.337 Comedy
# nm8789368,nm2414228,nm4857574 nm7973566,nm2933328,nm8789368,nm4857574 tvEpisode Mission Shrimpossible Game-Show
# \N \N tvEpisode Episode #5.236 Talk-Show
# nm1629095 nm1629095 tvEpisode L'home Tranquil \N
# \N \N tvEpisode Episode #5.3 Reality-TV
# nm10701807 \N short Recover Drama,Mystery,Short
# \N \N video Warning: Cute Pet Rat VS Frog - Live Feeding Documentary,Short
# \N \N short Some Unusual Birds Documentary,Short
# \N \N tvEpisode Episode dated 16 September 2008 News
# nm0363760 nm0363760 movie Irakleio Documentary
# \N \N tvEpisode Buon Appetito Documentary,Reality-TV,Short
# nm4604194 nm1853938,nm3476984,nm12305219,nm4607871,nm3083935 tvEpisode Episode #1.39 Family
# \N \N tvEpisode Jetzt reicht's mir aber! Family
# \N \N tvEpisode Episode #1.6214 News
# nm4928217 nm2459588 tvEpisode Episode dated 21 May 1948 Music
# \N nm5668420,nm6817686,nm4880566,nm6212318,nm8203568 tvEpisode Liquified Food Taste Test Comedy,Family,Talk-Show
# nm11894891 \N tvEpisode Episode #1.347 Drama
# nm0580319 nm0022674,nm0264977,nm0412698,nm0596913,nm1509740,nm0990401,nm1994791,nm1320140 tvEpisode Episode #3.49 \N
# nm0626965 \N movie Rewind Documentary,Drama
# \N \N tvEpisode Episode #8.18 Reality-TV
# nm11482135 nm11482135 short Trevor Short
# nm1884278 nm0875710,nm1279721,nm1994167 tvEpisode Charred Comedy,Drama
# nm1141435 \N video Fetisch - Schamlose Hingabe \N
# nm0538214,nm2634343 nm3119533 tvEpisode Episode #1.8470 Drama,Romance
# nm3766090 nm3766090 tvEpisode The Jungle Book Documentary,Short
# \N \N movie Leftovers \N
# nm0036397 nm3531283,nm0912726 tvEpisode Episode #1.9800 Drama,Romance
# nm0845625 nm1415329,nm0845625 tvEpisode Tårar av silver Adventure,Animation,Comedy
# nm0181745 nm0688071,nm0471763,nm2271587,nm0252012 tvEpisode Délices de Chine Crime,Thriller
# nm1130096 nm2591398 tvEpisode Episode #1.1600 Comedy
# nm9240052 nm9240052 tvEpisode Zero-G Episode 3: To vomit or not to vomit? \N
# \N \N tvEpisode Episode #1.3 Talk-Show
# \N \N movie Andrew + Amy \N
# nm1941244 nm6773130 tvEpisode The Stevie D. Show with Warren Michael and Billy Keane Talk-Show
# \N \N tvSpecial Hay que volver a empezar Musical
# nm0273084 nm0140092,nm1575405 tvEpisode Episode #1.47 Comedy,Drama,Romance
# nm3731214 nm3731214 tvEpisode The Lizards of Oz Reality-TV
# \N \N tvEpisode Electro Latex Straight Jacket Bondage Adult
# \N nm1415738 tvEpisode 3 meses de vida Comedy
# nm1578488 \N tvEpisode Episode #44.25 Family,Game-Show,Reality-TV
# \N \N tvEpisode Das Versuchskaninchen Crime
# \N \N tvEpisode Episode dated 7 September 2015 News,Sport,Talk-Show
# nm0758508,nm0075562,nm0086251,nm0484645 nm1309201,nm0124987,nm0260012,nm0608962,nm0041141,nm0049898,nm0057308,nm0107130,nm0110958,nm0138704,nm1603704,nm1604667,nm1309849,nm1227451,nm1209711,nm0313975,nm0318428,nm1080563,nm0453311,nm0461347,nm0501694,nm0519487,nm0546100,nm0720302,nm0740537,nm0767359,nm0783328,nm0268716,nm0268717,nm0564610,nm0650083,nm0928108,nm0303930 tvSeries Casey Jones Adventure,Western
# nm0001102,nm0035106 nm0926073,nm0245299,nm0564323,nm0035106,nm0001102 movie Rock 'n' Roll High School Comedy,Music
# nm2686295 \N short As they say Short
# \N \N videoGame NS-Shaft \N
# nm0792446 nm0792446 tvEpisode Toy Gun Adventure
# nm0735276 nm0104973,nm0351929,nm0937725,nm1631709,nm2650801,nm6895761,nm3282994,nm3640424 tvEpisode Kasual with a K Action,Crime,Drama
# nm0305493,nm0306236,nm1108994 nm0996348,nm1356167,nm0488665,nm1367531 tvEpisode Episode #1.197 Action,Adventure,Crime
# nm1659846 nm1659846 short A Malcriada Short,Thriller
# nm0519983,nm1760842 nm1288308,nm0764188 tvEpisode Episode #1.94 Drama,Romance
# nm7309581 \N short Body Dance Music,Short
# \N \N tvEpisode Looking for Reggie Comedy
# nm4491047 \N tvEpisode Episode #1.86 Talk-Show
# nm6695356 nm0297742 tvEpisode Nin'nin shugyo setto Animation,Comedy,Drama
# nm0091843 nm0091843,nm0618151 tvEpisode Deine letzte Chance Comedy,Crime
# \N \N tvEpisode Episode #1.109 Music
# nm0691540 nm0068074,nm0591517,nm1003798,nm1279184,nm0068347,nm0068589 tvEpisode Episode #1.6320 Drama,Romance
# nm0411152 \N tvEpisode Las Vegas - Part 2 Sport
# nm11598129 nm9491492,nm12426140 tvEpisode Episode #1.241 Drama
# \N nm2338252 tvEpisode Episode #1.202 Game-Show
# nm5425799 nm10998793,nm10998792,nm10998794 tvEpisode Episode #1.162 Drama
# nm0347364,nm1103067 nm5674681,nm5145735,nm5477572,nm4027076 tvEpisode Entrando Numa Fria Comedy
# nm10512210,nm10512209,nm3582934,nm8213447,nm8669327 nm6427250,nm9142902,nm1242272,nm10512211 tvEpisode Episode #1.668 Biography
# nm0080245 nm0619760 movie Thazhvaram Crime,Drama,Musical
# \N \N tvEpisode Episode #1.528 Drama,Reality-TV
# \N \N tvEpisode Binding Briella Adult
# nm0703028,nm0703029 nm0703028,nm0703029 short Alice in Not So Wonderland Animation,Short
# \N \N tvEpisode La zorrita vuelve al agujero Adult
# nm0579318 nm0005227,nm2889385,nm2620500,nm3035693 tvEpisode Uncle Gibbs Comedy,Drama,Romance
# nm5030928 nm5030928 tvEpisode Episode #1.256 Drama,Family
# nm0951766 nm5270004 tvEpisode Episode #1.1 Sci-Fi
# \N nm1121649 tvEpisode Deliver Us from Evil Comedy,Talk-Show
# nm3529203 \N tvEpisode What is Your Fantasy Sex Scene? Documentary,Talk-Show
# \N \N tvEpisode Episode #2.59 Comedy,Music,Talk-Show
# nm0615948 nm0268818,nm0615948 movie Vne Drama
# nm0062970 nm0083276 tvEpisode The Great Red Apes Documentary
# \N \N tvEpisode Episode #1.4513 News
# nm1283069,nm1431194 nm3541637,nm4497784,nm3931762 tvEpisode Episode #1.34 \N
# \N \N tvEpisode Chuck 2x10 REACTION!! "Chuck Versus the DeLorean" Talk-Show
# \N \N tvEpisode Episode #4.3 Documentary,Talk-Show
# nm0638528 nm0293750,nm0866572,nm0928611 tvEpisode The Big Water Adventure,Drama,Family
# \N nm2152369 tvSeries The Metal Detective Crime,Sci-Fi
# \N \N tvEpisode Episode #1.4 Drama
# nm3219751 nm3219326,nm3219751 short Hi! Kiko Mori Drama,Short
# \N \N tvEpisode Episode #1.3103 News
# nm2366663 nm9430973,nm5557400,nm4433772,nm4060831 tvEpisode Episode #1.271 Comedy
# \N \N tvEpisode Thurston vs. Stewart Crime
# \N \N tvEpisode Bad Influences Crime,Reality-TV
# \N nm1284743 tvEpisode Totem Talkers/The Wisdom Toad Animation,Family
# nm0147914,nm0608461 nm1223306,nm1693316,nm1271798,nm1236486 tvEpisode Episode #1.139 Comedy,Family,Fantasy
# nm3131807,nm2788669 nm1340699 tvEpisode Episode #3.143 Drama,Romance
# nm4300605 nm1626957,nm9688099,nm9671981,nm9688101,nm3828158,nm9688100 tvEpisode Peccati di gola Drama
# nm7910568 \N short Blonde Short
# \N \N tvEpisode Episode dated 21 January 1947 Comedy,Music
# nm4741169 \N movie Chankhe Shankhe Pankhe Comedy
# \N \N tvEpisode Episode #4.16 Drama,History
# nm10678642 nm1269722 tvEpisode Episode #1.390 Drama
# \N \N tvEpisode Talking to @Naval Ravikant About All the Important Stuff News
# nm1643039 \N short Casa Del Fauno Documentary,Short
# nm1448780,nm0134018 nm2253549,nm2254339,nm1064673,nm2279681,nm1302013,nm1367886,nm0733345,nm1985565,nm9819488 tvEpisode Episode #1.14 Comedy,Romance
# \N \N tvEpisode Episode #1.32 Drama,Romance
# nm4890000 nm7606693,nm7579393 short S.A.M: Sentient Automaton Model Comedy,Drama,Romance
# nm0145114 nm0308318,nm0575781 tvEpisode Episode #1.20 Drama,Romance
# nm7129099 \N tvSeries Alle mot 1 Game-Show
# nm0917513 nm0301126,nm0881067 tvEpisode Grann-gran Comedy,Drama
# \N \N tvEpisode Episode dated 17 September 2014 News
# nm7019609 nm7019609 movie Nirbandham 2 Crime,Drama,Thriller
# nm0829903 nm0607878,nm0177379 tvEpisode Nothing But the Tooth Comedy
# nm0777593 \N video Larger Than Life: The Making of 'Spine Tingler! The William Castle Story' Documentary,Short
# nm1845329 \N tvEpisode Celebrity News News
# nm0296651,nm0685923 nm0101147 tvEpisode Episode #1.10 \N
# \N \N video Wet Wet Wet: Wishing I Was Lucky - US Version Music,Short
# nm0485700 nm1093720 tvEpisode Charly und das geheimnisvolle Haus Comedy,Drama,Family
# nm0102537,nm0635620,nm1637779 \N tvEpisode American Dream Game-Show,Music,Reality-TV
# \N nm1221966 tvEpisode The Candidate: Part 4 Drama,Romance
# nm4032633,nm1802557 nm1802557,nm4032633 movie 4 3 2 Uno Drama
# nm0770375,nm0554045,nm1109922 nm0103839,nm0636799,nm3741339 tvEpisode Episode #1.89 Comedy,Drama,Romance
# nm7149567,nm9252359 nm9252359,nm7149567 tvEpisode Growing Up Comedy,Fantasy,Musical
# nm8332119 \N tvEpisode Episode #1.27 Crime
# nm8111604 \N videoGame Deijî chokorêto torikku Crime
# nm5061788,nm2332048 \N short Pulling Teeth Biography,Documentary,Short
# nm12316911 \N tvEpisode Allô Maman bobo Documentary
# \N nm0663789 tvEpisode The Circle of Life Adventure,Game-Show,Reality-TV
# nm8115227 nm1466348 video Dannebrog Music,Short
# \N \N tvEpisode Episode dated 10 May 1992 News,Talk-Show
# nm10919652 nm6352729 tvEpisode Episode #1.301 Drama
# \N nm1455797,nm2410690,nm1757950 tvEpisode Hemat*ology Documentary
# nm3762564 nm1563052,nm0912726 tvEpisode Episode #1.9916 Drama,Romance
# \N \N tvEpisode Otokotachi no kakugo History
# nm1119338 \N video Overfart Short
# nm2474204,nm5730808 nm2142138,nm5730808,nm0797520,nm4932106,nm2474204 tvEpisode How to Gut and Deep Fry a Fish Comedy
# \N nm12082627,nm3454608,nm12215989,nm5835143 tvEpisode Episode #1.152 Talk-Show
# \N \N tvEpisode Episode #1.7 \N
# nm11598167 nm11598177,nm11598178,nm11598179 tvEpisode Episode #1.63 Drama
# nm1737420 nm0420978,nm0000610,nm1737420 short Drift Drama,Short
# nm3639948 \N tvEpisode Episode dated 24 May 2012 Crime
# \N \N tvEpisode A Love Worth Fighting For Reality-TV
# nm0296355,nm2857817,nm2857750 nm2857750,nm0296355,nm2857817 tvSeries Auf Expeditionsreise Documentary
# \N \N tvEpisode Episode #5.1 Music
# \N \N tvEpisode Episode #1.11787 Drama,Romance
# nm0442345 nm0725300,nm3358499 tvMovie In den besten Familien Comedy
# nm1716662 nm1716662,nm3755273 short Riding the Saber Comedy,Short
# nm8194193 nm8194193 short The Fiddle (Der Fidl) Animation,Short
# nm1451137 nm0426169,nm0545713,nm0574509,nm3403085,nm0899531 tvEpisode Roomies Comedy
# \N \N tvEpisode Episode dated 19 September 2017 News
# nm0752244 nm0060712,nm0752244 tvSeries Bed & Breakfast Comedy
# \N \N tvEpisode La decepción de Joaquín Comedy,Drama,Romance
# nm0863990 nm0586965,nm0004766,nm1631709,nm0163694 tvEpisode Oh Golly Goth Crime,Drama,Mystery
# nm0292419 nm0390635 tvEpisode Victim of Circumstance Crime,Drama
# nm10642118 \N tvEpisode Episode #1.398 Drama,Family,Romance
# nm0926911 \N movie JLS: Only Tonight - Live from London Music
# nm1158692 \N short Blue Dreams Downtown Fantasy,Short
# nm6155745 nm2638275 tvEpisode Masayoshi Yamazaki & Tavito Nanao Talk-Show
# \N \N tvEpisode Vidal in Venice Documentary,History
# nm0680799 nm1028310,nm4397706,nm1130314,nm0287482,nm0363624,nm0382375,nm0518773,nm0769887,nm0877894,nm0995452,nm1032103 tvEpisode Hog Tide Action,Adventure,Animation
# \N \N tvEpisode Episode #2.152 Comedy,Music,Talk-Show
# \N \N tvEpisode Episode dated 23 October 1965 \N
# nm0015327 nm0015327 tvEpisode Nuri and Yasir Drama
# nm12591377 \N movie Karmugilu Drama
# nm0015570 nm0015570 tvEpisode Episode #1.3 Adventure,Drama,Romance
# \N \N tvEpisode Episode #10.226 News
# nm10608971 nm7370686 tvEpisode Episode #1.441 Romance
# nm2086668,nm0938642,nm2410739 nm5634732,nm1655705,nm1700803 tvSeries Haunted Case Files Horror,Reality-TV
# nm11517652 nm10641731,nm11257659,nm11539324 tvEpisode Episode #1.860 Drama
# nm5678976 nm5678976 short Searching for Disk Drama,Short
# \N \N tvEpisode Episode dated 5 October 2010 \N
# nm0892491 nm0343019,nm0892491 short Luna Horror,Short
# \N nm8186937 tvEpisode Episode #1.324 \N
# \N \N tvEpisode Episode #9.118 Comedy,Talk-Show
# nm0248054 nm2524496 movie Naked Fear Horror,Thriller
# \N \N tvEpisode Supernatural 15x4 REACTION!! "Atomic Monsters" Talk-Show
# nm3353684 \N tvEpisode John Mark Karr News,Talk-Show
# nm1252599 nm2630721 movie Of Dragons and Fawns Documentary
# \N \N tvEpisode Episode #3.1 Comedy
# \N \N tvEpisode Episode #1.42 \N
# \N nm8001464 tvSeries Delta Green Horror,Mystery,Thriller
# nm0762517 \N movie Saskin baba Comedy
# nm1323599 nm0272401,nm0366612,nm0434584,nm1213504,nm2151869,nm1698580,nm1649640,nm3631952,nm0721787,nm1860778,nm0833932,nm1802869 tvEpisode Episode #4.214 Comedy,Music,Talk-Show
# \N nm1361430 tvEpisode His Name Is Rios Comedy
# \N \N tvEpisode The Test Subject Adult
# nm0565214 \N tvEpisode Ultimate Tournament of Champions Round 1, Game 16 Game-Show
# nm2441823 nm4471918,nm2441823 short Susan Destroys the World Fantasy,Mystery,Sci-Fi
# \N \N tvEpisode Episode dated 13 November 2013 News
# \N \N tvEpisode Rôjin hômu wo erabu toki... Documentary
# nm6902426 nm6902426 short Wake Up and Hear the Music Comedy,Drama,Music
# \N nm0736411 tvEpisode Chi-Raq Documentary
# nm0276899,nm0667257,nm0682538 nm0060370,nm0103819,nm0547640 tvEpisode Episode #1.107 Drama,Romance
# nm0730743 \N short Capturing a Koala Bear Short,Western
# nm0649897 nm4002214,nm1883542 tvEpisode Episode #1.108 Drama
# \N \N tvMovie Wild Dog in America Documentary
# \N \N tvEpisode Ben Rector Talk-Show
# nm1208968 nm2757356,nm1889819,nm2049884,nm2624834,nm4416737,nm1210565,nm1768323 tvEpisode El dueño del mundo Adventure,Drama,Mystery
# nm0806631 nm0035422 tvEpisode Episode #1.7 Comedy,Drama
# nm9613486 nm11400830,nm11400831 tvEpisode Episode #1.744 Comedy,Drama
# \N nm5676306 tvEpisode Giants: Part 3 News
# nm5542667 \N tvSeries Stomatolog Drama,Romance
# \N nm0023817,nm0171687,nm0745538,nm0208150 tvEpisode Episode #1.2035 Comedy
# nm1180433 nm1136041 tvEpisode Episode #2.1 Documentary
# \N nm1107458 tvEpisode Episode #1.12296 Drama,Romance
# \N \N tvEpisode Episode dated 31 July 2020 \N
# nm0305876,nm0554929 nm2406112,nm0302201,nm0302204,nm1583648,nm1532678 tvSeries Amy, la niña de la mochila azul Drama,Family
# \N \N tvEpisode Episode dated 17 August 2001 Talk-Show
# nm0777029 nm0385940 tvEpisode Das Haus Comedy
# nm2243989 nm0596942 video Les Fourberies de Scapin Comedy
# nm11338299 nm11308400,nm11308401 tvEpisode Episode #1.92 Drama
# \N \N tvEpisode Du bist ganz tief drin, darf ich kommen? Adult
# nm2129968,nm10110016 nm8104883,nm3219731,nm2101268,nm2102050,nm4918960,nm10109991,nm9878307,nm10110015 tvEpisode Episode #2.100 Drama,Romance
# \N \N video Hairy Honies 2 Adult
# nm1027511 nm1048081,nm0192233 tvEpisode Automashic Comedy,Family
# \N nm4501677,nm5147563,nm8245357 tvEpisode Ek Kos Jeet Fantasy
# nm2185486 nm2185486 tvEpisode Bunker Fever Horror
# \N nm0003944,nm0676345 tvEpisode The Fifth and a Half Sense Animation,Family,Mystery
# nm2406892 nm2406892,nm3399230,nm3279655 tvEpisode Buyout Crime,Thriller
# \N \N tvEpisode The City-Wide Puzzle Game?! Puzzlemon's Rampage! Action,Adventure,Fantasy
# nm4673123,nm7169195 nm7169195 tvEpisode Episode #11.1 News,Talk-Show
# \N \N tvEpisode Episode #1.2095 News
# nm2226610 nm8216368,nm3713189,nm7208651,nm2226610 tvEpisode «Deville»: Die Weihnachtsshow mit Slam-Poetin Lara Stoll Comedy
# nm9098558 nm4354628 tvEpisode Episode #1.156 Drama
# nm2575302 nm1281893,nm0912726,nm1839448 tvEpisode Episode #1.7569 Drama,Romance
# \N \N tvEpisode Episode #1.29 Crime
# nm0511107 nm0972243 video XXX Channel Adult
# nm0728149 nm0665651 tvEpisode Episode #1.81 Drama,Romance
# nm0064723 nm1434269,nm0902535 tvMovie Die Gräfin von Rathenow Drama
# nm6158195 nm6158196,nm6158195 short From Minus One Drama,Family,Short
# nm0208571 nm0208571,nm0720938,nm12415877 tvEpisode La Fronde History
# \N nm2039645,nm1334627 tvEpisode Her-itage Moments Game-Show,Reality-TV
# \N \N tvEpisode Talking to Myself Comedy,Documentary,Music
# nm11686996,nm11686997 nm11686996,nm11686997 tvEpisode JOKER ***Spoiler Talk*** Therapy is in Session \N
# nm0888021 nm0465648,nm0888021 tvSeries De acteurs Drama
# nm1539146,nm0310494,nm1145806,nm1218169 nm1860656,nm1145257,nm1496040,nm1319679 tvEpisode Episode #1.78 Drama
# \N \N tvEpisode Episode #1.6 Game-Show
# \N \N tvEpisode She's a Cheater, I Need a DNA Test \N
# \N nm2459588 tvEpisode Episode dated 20 January 1949 Music
# nm0892144 nm0795748,nm0059949,nm0770886,nm0136333,nm0762976 tvEpisode Just Another Fox in the Crowd Comedy,Crime,Mystery
# \N \N tvEpisode Episode #2.16 Comedy,News,Talk-Show
# \N \N tvEpisode The Seven Ravens Comedy,Horror
# nm0874133 nm0358950 tvEpisode Hedy's Happy Holiday House Comedy,Drama,Family
# nm9512644,nm9512645 \N movie Plant Codes, Unleashing Nature's Healing Power Documentary
# nm12090040 nm12090040 short Not Scared... Short,Thriller
# nm1741648 \N tvEpisode Payment Day Reality-TV
# nm6083966 \N short Cyril Wolverine - Animals Asia Musical,Short
# nm0970473,nm1432225 nm0970096 tvEpisode Episode #1.143 \N
# \N \N tvEpisode 1 September 2019: Late Bulletin News
# nm0957434 nm2468765 tvEpisode Episode #8.90 Action,Adventure,Crime
# \N \N tvEpisode Bene Mayr Sport
# nm5101783 \N tvEpisode Capture a Crocodile Documentary
# \N \N tvEpisode Episode #1.20 Comedy,Drama,Mystery
# nm0858686 nm0283888,nm0365829 tvEpisode The Banter Bloodbath Action,Animation,Comedy
# \N \N tvEpisode Top 10 Plot Points That Were Cut Out of Movies Comedy,Talk-Show
# \N \N tvEpisode Episode dated 22 January 1990 Talk-Show
# nm1212770,nm0010500,nm0062879 nm1282374,nm1293423 tvEpisode Episode #1.355 Crime,Drama,Romance
# nm2329841 nm4607871,nm3083935 tvEpisode Episode #1.516 Drama,Romance
# nm0082676 nm0669124 tvEpisode No Boys Allowed Comedy
# \N \N tvEpisode Can a Lifetime of Excess Weight Lead to Heart Disease? Documentary
# nm12242171 nm12242171 short The Red Death Horror,Short
# nm1008406 nm1212019,nm1240754,nm1754469,nm0647690,nm0748906 tvEpisode Episode #3.43 Drama
# \N \N tvEpisode Episode #1.52 \N
# nm9576701,nm1818043 nm7418837,nm9885415,nm3572859,nm6650531,nm9885416 tvEpisode Episode #1.163 Comedy,Family
# \N \N tvSeries Blaggers Banquet Reality-TV
# \N \N tvEpisode Programa exibido em 13/04/1989 Comedy
# \N \N tvEpisode Gun Awareness Reality-TV
# nm8901784 \N tvEpisode Episode #1.137 Biography
# nm0089711 \N tvSpecial CinéFashion Film Awards 2016 \N
# nm0019464 \N short Wah! Maan Gaye Ustad Short
# \N \N tvEpisode Welcome to Darkshadow University Animation
# nm5183850,nm0689767 nm1549896 tvMovie Yego otpusk Drama,Romance
# \N \N tvEpisode Episode #27.10 Game-Show
# \N \N tvEpisode All Hail the Anal Queen Adult
# nm4275597 nm12880805 tvEpisode Curiosity Horror,Mystery,Short
# nm0270570 nm0121154,nm0755967 tvEpisode Hulkus Pocus Drama,Fantasy,Mystery
# nm0934525 nm0859432 tvEpisode Years, Continents, Bloodshed Crime,Drama,Mystery
# \N \N tvEpisode Actress & Author - Laura Aguinaga Talk-Show
# \N \N tvEpisode Episode dated 18 September 2017 Talk-Show
# nm6908650 nm5203198,nm7006227,nm6908651,nm9115585,nm9115586,nm9115584 tvEpisode Episode #1.3040 Drama
# nm1352415 \N tvEpisode Episode dated 26 February 1991 Game-Show
# nm0030420 nm1903924 tvEpisode Yubiwa ga kiechattan Dashi Animation,Comedy,Fantasy
# nm7408484 \N tvEpisode Episode dated 9 April 2015 Comedy
# \N \N tvEpisode One of Our Own Crime,Drama
# nm1407652 \N tvEpisode Episode dated 8 September 1987 Music
# \N \N tvEpisode The Deep State Coup News
# \N \N tvEpisode Episode #1.5 Romance
# nm1165556 nm1604666,nm0715087,nm5492177 tvEpisode Episode #1.3838 Drama,Romance
# nm0797382,nm1111912 nm1111912 video Way to Love Adult,Drama
# nm1564838 nm11774025 tvSpecial Jack White aux Eurokéennes de Belfort Music
# \N \N tvEpisode Episode dated 4 February 2016 News,Talk-Show
# \N \N tvEpisode Episode #1.35 Reality-TV
# nm11275933 nm11275933 tvEpisode Episode #1.859 Comedy
# nm5667113 nm5667113 short Aroma-Sed Drama,Short
# nm3326145 nm3326145 short Desibel Short
# nm4116553,nm4417801 nm4116553,nm4417801 tvEpisode Good Advice, British Advice Comedy
# nm6787909 \N tvEpisode Nora en Tinne krijgen een nieuwe collega Drama
# nm0790237,nm3150680 nm3538945 tvEpisode Ogon Crime,Drama
# \N \N tvEpisode Episode dated 13 July 2020 \N
# nm0831664 nm0831664 short Actors Anonymous Comedy,Short
# nm0460295 \N tvEpisode Episode #16.10 Comedy,Music
# \N \N tvEpisode Episode #4.33 Talk-Show
# \N \N video Parmish Verma: Sab Fade Jange Music,Short
# nm10697266 nm10697275 tvEpisode Episode #1.66 Drama
# \N \N video Gladys Knight & Boyz II Men: End of the Road Music,Short
# nm2212268 nm8798545 tvEpisode Episode #1.2732 Comedy
# \N \N tvEpisode Starved for Attention Documentary,Family
# nm4913116 nm4913116,nm9216015 short Arc Sci-Fi,Short
# nm5382976 nm2708928 tvEpisode Episode #1.285 Family
# nm9412189 nm10476119,nm12664327,nm0438471,nm6446531 tvEpisode Episode #1.388 Drama
# \N \N tvEpisode Episode #1.3 Drama
# nm6833072,nm9750986 nm8042385,nm9957701 tvEpisode Episode #1.197 Family
# \N \N tvEpisode Thaïlande - Bangkok - 1ère partie Documentary
# nm2527367 nm5303260,nm7481850,nm2527367 tvSeries Haunted Objects Horror
# \N \N videoGame Kurimuzon kuran Action
# nm0826320 nm3343273,nm1199673,nm7526480,nm7434147,nm7488584 tvEpisode Episode #1.137 Comedy,Family
# nm0485747 nm0311903 tvEpisode Episode dated 21 March 1965 Short
# nm0499918 nm0499918 short Keidas Documentary,Short
# nm0343464 nm0539488,nm0411493 movie Ha-Martef Drama
# \N \N tvEpisode Episode dated 31 July 2007 News,Sport
# nm0386303 nm0409323 tvEpisode Jigorô sono ai, seishun todô-hen Action,Animation,Comedy
# nm10947360 nm3137021,nm1295053 tvEpisode Episode #1.223 \N
# \N \N tvEpisode Episode #1.709 Drama
# \N \N tvEpisode Episode dated 14 December 1988 \N
# nm0761055,nm6108603 nm1471503,nm1427302,nm2292491,nm6544421 tvEpisode Sonia comienza a sentir algo por León Drama,Romance
# \N \N tvEpisode Episode dated 8 August 2005 Comedy,Talk-Show
# \N nm1471121 tvEpisode The Heart and Soul of the NWO Action,Sport
# \N \N tvEpisode Johnny and the Love Bug/The Twenty-Foot Root Family,Music,Short
# nm5577396 nm4967281,nm7583058 movie Kohinoor Comedy,Thriller
# nm1923042 nm1923042,nm12448389,nm2012803 tvEpisode Episode #1.48 Drama
# nm0064415 \N short Artful Artists Comedy,Short
# nm0001743 nm0223838,nm1072798,nm0636157 tvEpisode Destiny Action,Adventure,Fantasy
# nm0754586,nm1441484,nm1450550 nm1866758,nm1410260,nm1415620,nm1474571,nm1862165 tvEpisode Episode #1.17 Comedy,Drama,Romance
# nm5249894,nm3747914 nm3747914 tvSeries You, Me and That Other Guy Comedy
# \N \N video Smokey Robinson: Old Fashioned Love Music,Short
# \N \N tvEpisode Episode #1.4 Comedy
# \N \N video Blade Runner 2049: Designing the World of Blade Runner 2049 Documentary,Short
# \N \N tvEpisode Round 20: West Coast vs Melbourne Sport
# \N nm8528265 videoGame Pocket Tanks \N
# \N \N tvEpisode Episode #1.682 Talk-Show
# nm11637689 nm12279974 tvEpisode Episode #1.45 Drama,Romance
# \N \N tvEpisode Isolating Living Alone Vlog #1: This Is Going To Be Interesting Reality-TV
# \N \N tvEpisode Return of the Living Dead: Part III (1993) Horror
# nm4323528 nm4323528 movie Bulan dan Pria Terhebat Action,Comedy
# \N \N tvEpisode Episode #1.6 Music
# nm1847706 nm1049081,nm1187873,nm1073100,nm11929219,nm2059457,nm2204042,nm2379753,nm4380835,nm7311398,nm8520520 tvEpisode Episode #13.8 Comedy,News
# \N \N tvEpisode Falling from Grace Comedy
# \N \N tvEpisode Episode #2.11 News
# \N \N tvEpisode Saffron Burrows/Brian Posehn/Swingin' Utters Music,Talk-Show
# \N \N tvEpisode Episode #2.1 Action,Comedy,Fantasy
# nm3562320 nm12359879,nm2518686,nm11353990,nm12373700,nm10283735 tvEpisode Episode #1.239 Drama,Family
# \N \N tvEpisode Episode dated 18 September 2002 Family
# \N \N tvEpisode Episode #1.33 Drama,History,Romance
# nm6974897 nm6974897 short Nado de Invierno Drama,Short
# \N nm0646709 tvEpisode Episode #1.2 Drama
# \N \N tvEpisode Episode dated 1 June 2008 Music,Reality-TV
# \N \N tvEpisode Episode dated 23 May 1974 Comedy,Talk-Show
# \N \N tvEpisode Physician Heal Thyself Comedy
# nm5299129 nm1017767,nm5298253,nm5298318 movie Hak se wui dong on: Hak gam dai gwok Crime,Thriller
# nm1946247,nm4470619,nm1855392 nm7420000,nm4890580 tvEpisode Bhootiya Hotel Crime,Drama,Mystery
# nm0003477 nm0115473,nm0493351,nm0003477,nm1131508 tvEpisode Episode #1.75 Comedy,Talk-Show
# \N \N video Robocock Adult
# nm5674629 nm5674629,nm5674129 movie #Starvecrow Drama,Thriller
# \N \N tvEpisode Episode #1.57 Drama,Romance
# nm0684461 nm4424314 tvEpisode The Booklyn Brother Beat the Best News
# \N \N tvEpisode Deutsche Funkausstellung Stuttgart - 28.08.1965 Music
# \N nm0068074,nm0808801,nm0068347,nm0068589 tvEpisode Episode #1.2742 Drama,Romance
# nm1791143 nm0872209 tvEpisode Do You Want to Die? Crime,Documentary
# \N \N tvEpisode Episode #1.93 Horror
# \N \N movie Something's Haywire - An interview with Jack O'Halloran Documentary
# \N \N tvEpisode Episode #1.266 News
# nm3526993 nm3526993,nm2828485 short The Robbery Action,Comedy,Crime
# nm3151947,nm5525942,nm5524246 nm5537458,nm4591419,nm5035583,nm5524246,nm5537626,nm5043370 tvEpisode Episode #11.9 Drama
# \N \N tvEpisode Episode #1.27 Animation,Comedy,Family
# nm0015846,nm0704479 nm1615030 tvEpisode Episode #1.152 \N
# nm0955161,nm0042771,nm0051678,nm0561336 nm0140092,nm0705107,nm0854137 tvEpisode Episode #1.114 Comedy,Drama,Romance
# nm1590975,nm3700573,nm0564796 nm1115084,nm1100677 tvEpisode Mighty Night/Water Ways Animation,Family
# nm6839281 nm1078542,nm4060172 tvEpisode Episode #3.156 Comedy,News
# \N \N tvEpisode Niño nadie News,Talk-Show
# nm0944315 \N tvEpisode Episode dated 14 August 2013 Talk-Show
# nm12622072 \N video Ball Honeys Adult
# nm0304305 nm0959322 tvEpisode La corrupción de la Toñi Comedy
# nm0130509,nm1202249,nm0053609 nm0844327,nm1804726,nm2808738,nm0034201,nm0182911,nm1738748,nm10318839,nm5375579 tvEpisode Épisode 88 Comedy,Crime,Drama
# nm1116394,nm6079450,nm4305738,nm7176105,nm8947647 nm6079450,nm7176105,nm8947647,nm8959296 tvSeries Brutal Reptiles Comedy
# \N \N tvEpisode Hidden Cam: 'Pregnant' Transgender at Planned Parenthood! Comedy,Talk-Show
# nm8213447 nm0961391,nm10018774,nm4726661 tvEpisode Episode #1.115 Biography,Drama,History
# nm2219198 \N tvEpisode Jim Carrey Biography
# \N \N tvEpisode Episode dated 20 January 2012 \N
# \N nm0483348,nm0722349 tvEpisode Episode #1.1 \N
# nm12352387 nm12352387 tvSpecial Object nightmare: fries and fires Animation
# \N \N tvEpisode 1971 United States Grand Prix Sport
# nm1628235,nm1856745 nm7816909 tvEpisode Episode #1.43 Comedy,Family
# \N \N tvEpisode Episode dated 13 November 1974 News
# \N \N tvEpisode Episode dated 26 December 2007 \N
# \N \N tvEpisode Episode dated 9 September 2004 \N
# nm2144365 nm2488134,nm3385607,nm0804679 tvEpisode Tri sudicky Comedy,Drama,Romance
# \N \N tvEpisode Episode dated 25 April 2018 \N
# nm0894583 nm0401392,nm0656670 tvEpisode Sabotage in Space Drama,Family,Sci-Fi
# \N \N tvEpisode Episode #1.4281 News
# nm10281387,nm10281386,nm6344686,nm10025830,nm1966600 nm10281385,nm3813965 tvEpisode Episode #1.171 Drama
# nm3815603,nm5345941 nm3815603 short Genewration Comedy,Short
# \N \N tvEpisode Episode dated 28 June 1999 News
# nm5149543 \N video My Old Man and the Sea Adventure,Family,Short
# \N nm0438471 tvEpisode Anurag, Prerna's Odd Meeting Drama,Romance
# \N \N tvEpisode Episode #1.3738 Talk-Show
# nm3644868 \N short Insu Light Short
# \N \N tvEpisode Episode dated 6 February 2001 Music,Talk-Show
# nm0769899 \N short In the Eye of a Genius Biography,Short
# \N \N tvEpisode Episode dated 1 June 2020 \N
# \N \N movie Settled on the Edge Action,Drama,Romance
# \N \N tvEpisode Green Bay Packers vs. Minnesota Vikings Sport
# nm11537103 \N tvEpisode Episode #1.1300 Drama
# nm10886194 nm10886194 short Sens chronicles visio Fantasy,Horror,Short
# nm0217782 \N movie Dromen van Holland Documentary
# nm3815014 nm5744244,nm6004820,nm1876616 tvEpisode Episode #1.37 Drama
# nm10148469,nm10164509 nm10148469 short La niña de la foto Horror,Short
# nm8017790 \N movie Hirakitai toshi goro \N
# nm8775119 nm8775119,nm8775120 short Stalk to Abandoned Kindergarten Adventure,Short
# nm7083625 nm7083625 short Temps mort Short
# \N nm1626604 tvEpisode Mothman Documentary,History,Mystery
# nm2773234,nm3329116 nm3329116 short Memory Reloaded Sci-Fi,Short
# nm0936451 nm0296491,nm0455404 tvEpisode Episode #4.2 Comedy,Drama,Family
# \N \N tvEpisode 'Dîner de cons' Talk-Show
# nm7443833 nm0086404 short Travellers: allegro vivace Drama,Short
# \N \N tvEpisode Percy Comedy
# nm0474848 nm1853938,nm2276735 tvEpisode Episode #1.18 Family
# nm9209376 \N short Classroom in the Air Documentary,Short
# nm0022172,nm0757877 nm0308318,nm0327964,nm0721201,nm0898247 tvEpisode Episode #1.163 Drama,Romance
# \N \N tvEpisode Episode #1.81 Comedy,Talk-Show
# \N \N tvEpisode Episode #8.2 Sport
# nm0056355,nm0836809,nm0686121 nm1075980,nm0067598,nm0781746,nm0836809 tvEpisode Episode #1.25 Comedy,Drama,Thriller
# nm8861919 nm8861919 short Shelley House Drama,Short
# \N \N tvEpisode Avatar: The Live-Action Bender Talk-Show
# nm1622141 nm1048669 video Chase: Cut Short Drama,Short
# nm0448395 nm0463989 tvEpisode Falsche Liebe Crime
# nm0752287,nm0737880,nm0700545 nm1368206,nm1644621 tvEpisode Episode #2.50 Drama,Romance
# nm2033794,nm0727972,nm1020314 nm1084215,nm1082284,nm1320353 tvEpisode Episode #2.65 Comedy,Romance
# nm2665583 nm2665583,nm1512370,nm3767874,nm1261051 tvEpisode AZ STORIES: AZ150 Preview - part 1 Sport
# \N \N tvEpisode The Celts Documentary,History,Mystery
# nm4576442 \N tvEpisode Episode dated 12 December 2001 Family
# nm0166836 nm0924065,nm0817809 movie Hook Line and Sinker Comedy,Romance
# nm0829985 nm0068074,nm0956789,nm0068347,nm0068589 tvEpisode Episode #1.4118 Drama,Romance
# nm10357998 nm10357998 tvEpisode Episode #1.830 Drama,Romance
# nm10149731 nm10149731 short Large Scale Absurdities, Vol.2 Animation,Comedy,Short
# nm9454991 nm6427250,nm4246495 tvEpisode Episode #1.338 Crime,Musical,Mystery
# \N \N tvEpisode Episode dated 8 July 2019 \N
# \N \N tvEpisode Episode #1.14 Drama,Romance
# nm3054983 \N video Generando Sufrimiento Music,Short
# nm0195270 nm0275585 tvEpisode Episode #1.62 Drama,Romance
# \N nm0107625,nm0490705 tvEpisode Episode #5.54 Action,Family
# \N \N tvEpisode Episode dated 25 January 2011 News,Talk-Show
# \N \N tvEpisode Episode #1.13 Action,Sport
# nm12482113 \N tvEpisode Chrissy Costanza ft. Harry Mack Game-Show
# \N nm2320866 tvEpisode Buried Alive Comedy,Fantasy,Horror
# nm12380167 nm12410401,nm12410394,nm12410503,nm12410393,nm12410397,nm12410398,nm12380167,nm12410396,nm12410395,nm12410402,nm12410400,nm12410399 tvEpisode If Minecraft was Weird Comedy
# nm10948446 nm10948446 tvSeries Galiyaara: Into the Alleyways \N
# nm0365666,nm0005522,nm0267495,nm0028982 nm1403671,nm0005522,nm2931346,nm6629803,nm0028982,nm1344603,nm1446971,nm8520307,nm2839165 tvSeries Superstition Drama,Fantasy,Horror
# \N nm10830822,nm4058310 tvEpisode Porn, Sex & Squeegees With Dr. Nikki Goldstein Talk-Show
# \N \N tvEpisode Episode dated 1 November 2010 News,Talk-Show
# \N \N tvEpisode Episode dated 26 July 2004 News,Sport
# \N \N tvEpisode Double Shark Attack Documentary
# nm2591307,nm5028382 nm0786034 tvEpisode Episode #1.262 Drama
# \N \N tvEpisode Episode #1.82 Comedy,Drama,Romance
# \N \N video Debbie '99 Adult
# \N \N tvEpisode Episode dated 4 April 1980 \N
# nm7866383,nm7866382 nm7866383 tvEpisode Tennis Highlights Animation
# nm10611234,nm12394275 nm12609949,nm5612873 tvEpisode Episode #1.115 Drama,Romance
# nm0035630 \N video Fallen II: Angels & Demons Adult,Drama,Fantasy
# nm2346949 nm2346949 short Górnicy '88 Documentary,Short
# nm8663836 nm8663836,nm10076279 tvEpisode On the Edge Comedy,Drama
# nm0804973 \N tvEpisode Episode #6.258 Game-Show
# nm3154374 nm0324477,nm1479331,nm0329985,nm4376824,nm5263849,nm5704922,nm2563808,nm9027562 tvEpisode Blackout/Parchawi Comedy
# nm4498251 nm4498251 tvEpisode Barbie Faces Backlash for Not Being Inclusive Enough Talk-Show
# nm0113663 nm0621808 tvEpisode Episode #1.1803 Drama,Romance
# \N \N tvEpisode Dragon: The Bruce Lee Story (1993) Action,Animation,Documentary
# \N \N tvEpisode Grant Hayes: Grant Hayes Trial Testimony - Day 10 Pt 5 Documentary
# \N nm4512533,nm4512041 tvSeries Quinquis Comedy,Drama
# nm3925072 nm9030327 tvEpisode You're Gonna Need a Bigger Plenum Reality-TV
# nm12658229 nm12658229,nm12658230 short Pigeons attack 2 Action,Short
# nm11668681 nm7080784 tvEpisode Episode #1.83 Drama
# \N \N tvEpisode Chrissy Marie Naive Burglar Bound Adult
# \N \N tvEpisode Episode dated 18 November 2019 News,Talk-Show
# nm1436327 nm1436327 movie The Staremaster Documentary
# \N \N tvEpisode Episode #3.10 Reality-TV
# \N \N tvEpisode Halloween Fairy Makeup Tutorial \N
# \N \N tvEpisode Episode #1.3347 News
# \N \N tvSeries Bits and Bytes 2 Documentary
# nm0996320 \N tvEpisode Episode #1.63 Drama
# nm0163776 \N video Euro Angels 19: Pucker Fuckers Adult
# nm0826873 nm0075344,nm0500494 tvEpisode Night Drive Comedy,Drama
# nm2905618 nm2905618 tvEpisode Over a Film by Attila Adventure,Biography,Comedy
# \N \N tvEpisode Episode #10.248 Animation,Family
# \N \N tvEpisode Dierks Bentley Music,Reality-TV
# nm4492923 nm5888741,nm4492923 tvEpisode Episode #3.6 Comedy
# \N \N tvEpisode Episode #5.17 Comedy,Game-Show,Reality-TV
# nm9569748 nm7620177 movie Evil Dead is Back Horror
# \N \N tvEpisode Episode #2.3 Drama
# nm4675771 \N tvEpisode Brandon Routh - Wizard World Comic Con Des Moines Talk-Show
# \N \N tvEpisode Sk Movies Show #191: Furious Box Office & Suicide Squad Talk \N
# \N \N tvEpisode Fact Check False News
# nm4631428 nm4631428,nm4639497,nm4643429 short The Universe Thing Comedy,Fantasy,Sci-Fi
# \N \N tvEpisode News News
# nm0594084,nm0283253,nm0632812 nm0946695,nm2019778,nm0157123,nm0765126 tvEpisode Maze of Despair Action,Adventure,Animation
# \N \N tvEpisode Episode #1.3383 \N
# \N \N tvEpisode Episode dated 24 April 2015 News
# \N \N tvEpisode Episode #4.7 Talk-Show
# nm4246283 nm4246283 short Vendetta Action,Short
# nm6666863 nm6666863 short Wir lieben Alltag Comedy,Reality-TV,Short
# \N \N tvEpisode Episode #11.103 Drama,Talk-Show
# nm0071560 nm0363409,nm0931555 movie Lone Texas Ranger Western
# \N \N tvEpisode Episode dated 20 November 2015 Reality-TV
# \N \N tvEpisode Episode #1.1 Game-Show
# nm0046995 nm3317521,nm0514908,nm0656655 movie Jin da ban de zui hou yi ye Drama
# nm5422403 nm4072791 short 5º Izquierda Short
# \N \N tvEpisode Episode 09 \N
# \N \N tvEpisode Episode #1.36 Comedy,Romance
# nm12166615 nm12166615,nm12234923,nm0502352,nm0706189,nm12234924 movie Das Weyerhuus Drama,Mystery
# nm2487132 nm2487132 tvEpisode Episode #1.15 Music
# nm0275113 nm0475823 tvEpisode Tenias un lunar, querido Comedy
# nm1822793,nm5511501 nm1822793,nm5511501 tvEpisode Episode #2.11 Adventure,Comedy,Sci-Fi
# nm0521417 nm1250701,nm2504449 tvEpisode Episode #1.5 Action,Crime,Drama
# nm10819314 nm10819315,nm10819316,nm10819314 tvEpisode Yükselisten sona dogru Documentary,History,War
# nm0575546 nm0427161 tvEpisode The Executioners: Part 2 Crime,Drama,Mystery
# nm0675139 nm0805994,nm2030456,nm0510028 tvEpisode A Dance on the Dark Side Action,Crime,Drama
# \N \N tvEpisode February 14th, 2016: Part 2 Comedy,News
# \N \N tvEpisode Episode dated 15 November 2015 Talk-Show
# \N \N tvEpisode Lv Shui Qing Shan Gong Yi Ji - Episode 2 Reality-TV
# \N \N tvEpisode I Funyun So Hard Comedy
# nm0694260 nm0367517 short Woman Against Woman Drama,Short
# \N \N tvEpisode Guest Star: David Joy Family,Music
# \N \N tvEpisode Episode dated 3 July 2018 \N
# nm8516371 \N video Jall! Activewear Campaign Short
# \N \N tvEpisode Episode #1.86 Crime,Drama,Mystery
# nm11553602 nm11553606,nm11553604,nm11553605 tvEpisode Episode #1.166 Drama
# \N \N tvEpisode Two Knotty Boys - Live Workshop Adult
# nm8686462 nm8686462 tvMovie Fly Traders Presents Dick Gregory Documentary
# nm0276886,nm0303114 nm0451891,nm0928492 tvEpisode Salomé Drama
# nm1020307 nm0941610 tvEpisode And Lead us not into Temptation Comedy
# nm1662715 nm2293981,nm0599413 tvEpisode Cuestión de posibilidades Comedy,Drama
# nm9480218 nm9534561,nm6638676,nm9480218 tvEpisode Accord pariétal souhaitable \N
# \N \N tvEpisode Episode dated 20 December 2018 Talk-Show
# \N \N tvEpisode Episode dated 25 July 1995 Talk-Show
# nm7675149 nm7675149 short Fatal Declare Crime,Horror,Short
# \N \N tvEpisode Episode dated 11 September 2014 News
# nm2133839 nm5406190 tvEpisode Victoria's Secret Comedy,News
# nm0926526 nm0275486,nm1863572 tvEpisode Anna Howard Shaw Day Comedy
# \N nm2279681 tvEpisode Episode dated 31 January 2018 Action,Adventure,Drama
# \N \N tvEpisode Episode #5.306 News,Talk-Show
# \N \N tvEpisode Episode dated 30 January 2009 Comedy,Talk-Show
# nm2566383 \N tvEpisode Optimise Documentary
# nm0260106 nm1520870,nm0523541,nm1515231 tvEpisode Episode #1.22 Drama,Romance
# nm1834600 \N tvEpisode Episode #14.58 Talk-Show
# nm1074921 nm1074921 tvEpisode Josie's First Birthday Documentary,Reality-TV
# nm8697041 nm8697041,nm10838149 tvEpisode Episode #5.197 Crime
# \N \N tvEpisode Episode #1.9 Documentary
# \N \N tvEpisode The Car Wash: learn colors with Ethan the Dump Truck Animation,Family
# ...
# \N \N tvEpisode Neureiche Schwester niestet sich bei Bauarbeiter-Familie ein Crime,Drama
# \N \N tvEpisode Episode #1.6 Documentary
# nm0520419 nm0340599 short All the World's a Stooge Comedy,Short
# \N \N tvEpisode Aventuras en Acapulco Comedy,Family
# nm0565214 nm0341311 tvEpisode Episode #34.22 Game-Show
# \N \N tvEpisode Mont-Royal Documentary
# nm12507211 nm12507211 short Sandwiched Short,Thriller
# nm7673077 nm7673076,nm5011375 short Becoming Mermaid Fantasy,Short
# \N \N tvEpisode Audrey Holiday Fucked in Fishnets 4k Adult
# \N \N tvEpisode Episode dated 13 August 1998 Game-Show
# nm2139524 nm2139524 short City Lights Drama,Fantasy,Romance
# \N nm0630035 tvEpisode Fantasy Factory's Sketchiest Moments Comedy,Reality-TV
# nm1455058 nm1455058 movie Between Two Cinemas Biography,Documentary
# \N nm9445171 video Blades of Steel Documentary,Short
# \N \N short Siena e dintorni di Vicovaro Documentary,Short
# \N \N tvEpisode Episodio 2 Comedy
# nm2606719 \N tvEpisode Episode #3.7 Comedy,Drama,Romance
# nm0489376,nm0296817 nm0244672 tvSeries Le compagnon \N
# \N \N tvEpisode Top 10 Most Extremely Dangerous Dinosaurs Comedy,Talk-Show
# \N \N tvEpisode Episode #1.14 Comedy,Family
# nm0623545 \N video Dim'at Shekherezada Documentary,Musical,Short
# \N \N tvEpisode Episode #1.14 Animation,News
# nm1656218 nm1656218 short En plan romántico Comedy,Short
# \N \N tvEpisode Paint Reality-TV
# \N \N tvEpisode Episode #15.183 Talk-Show
# nm3644248 nm3644248 short The Portrait Drama,Short
# \N \N video Hairy Tales Adult
# \N \N video The True History of Fashion Sluts Adult
# nm9329326 \N video Harrdy Sandhu: Kya Baat Ay Music,Short
# \N \N video Deep Inside Alex Jordan Adult
# nm1899494 nm1892508,nm1899494 video Barbara Carrera: Return to the Island Documentary,Short
# nm5053760 nm5141199,nm5054027 tvEpisode Episode #1.795 Drama
# nm0600353 nm0934807 tvEpisode Episode #1.1272 Drama,Romance
# nm1070740 nm1070740 short Tarfala Adventure,Documentary,Short
# \N \N tvEpisode The Undersea World of Jacques Cousteau: Whales Documentary
# nm1467975 \N tvSpecial Presente de Natal Music
# \N \N tvEpisode Resident Evil actress Sara Coates discusses Marguerite baker and Luiza Talk-Show
# \N \N tvEpisode Palawan Reality-TV
# nm10611234,nm12394275 nm12609949,nm5612873 tvEpisode Episode #1.556 Drama,Romance
# \N \N tvEpisode Episode #1.5 Reality-TV
# nm0442308 nm0750509,nm4689613,nm1050494,nm3664061,nm5119599 tvEpisode Episode #1.1242 Drama,Romance
# \N \N tvEpisode Domestic Abuse or Working the System?! Crime,Reality-TV
# \N \N short The 'St. Paul' Outward Bound Documentary,Short
# nm0036977 \N movie Sound and Fury Documentary
# nm7750699 nm7750699,nm11013094 short Fright Documentary,Short
# nm0253320 nm0253320 video Intro to Forbidden Zone: Director's Cut Comedy,Short
# nm11676508 nm11676508 video Fuck the Devil Horror
# nm1207262,nm3424898 nm1472530,nm0323558 tvEpisode Premier Comedy,Drama,Romance
# nm0534365 nm1757251 tvEpisode Toddler on the Run Drama
# nm12250794 \N video Niska Feat. Maître Gims: Elle avait son Djo Music,Short
# nm2372416 nm1804604 tvEpisode Tod einer Notärztin Crime
# nm1628224 nm1628224 movie In the Name of Buddha \N
# nm0132301,nm3626241 nm2468035,nm0132301 tvEpisode Sxip Shirey Music
# nm1307018 nm1108248,nm1108249,nm1584126,nm5701762 tvEpisode Bride of Bunnicula Adventure,Animation,Comedy
# \N \N tvEpisode The Blonde in the Pond Fantasy,Sci-Fi
# \N \N tvEpisode Christmas Special 2016 Talk-Show
# \N nm0480782 tvEpisode Episode #1.3267 Drama,Romance
# nm0832559,nm0500576 nm0596170,nm0832559 movie The Bridge at Midnight Trembles Documentary
# nm0126906 nm0780946,nm0123480,nm11849197,nm0234638 tvEpisode Espace Détente Comedy,Crime,Drama
# \N nm0072760,nm0504513 tvEpisode Episode #1.2 Comedy
# nm1259204 nm8827506 tvEpisode Episode #1.133 Comedy,Game-Show
# \N \N tvEpisode Episode #5.3 Comedy
# \N \N tvEpisode Episode dated 10 May 2004 Comedy,Horror
# \N \N tvEpisode Sherlock 2x1 REACTION!! "A Scandal in Belgravia" Talk-Show
# \N \N tvEpisode Episode #1.11 Romance
# nm0001124,nm0002177 nm0073238,nm0169318 movie The Master Mind Crime,Drama
# nm3213427 nm11088737 tvEpisode Episode #1.351 Romance
# nm1441489 nm1328861 tvEpisode Scott Kane Music,Sport,Talk-Show
# \N \N tvEpisode Kari no Hi no butsu \N
# nm1856836 nm1665588 tvEpisode Episode #3.27 Comedy
# \N \N short The Hit Action,Short
# \N nm0023817,nm0171687,nm0745538,nm0208150 tvEpisode Episode #1.2560 Comedy
# \N \N tvEpisode Last Season Game-Show
# nm3842343,nm3813822 nm3842343,nm3813822 tvEpisode Episode dated 28 July 2004 Game-Show
# nm0330665,nm1256147,nm2119854 nm0150058,nm0382375,nm0080588,nm1965374,nm1920946,nm3365259 tvEpisode Cooking with Claw/Catnipped in the Bud Action,Adventure,Animation
# \N \N tvEpisode Episode #1.18 \N
# nm0000186 nm0000186 tvEpisode 5/24/20 Comedy,News
# nm1821883 \N video I Am Asa Akira 2 Adult
# nm0595229 nm0293955,nm0769653 tvEpisode Glacier Canyon Adventure,Drama,Family
# nm8139688 nm1957817 tvEpisode Fernanda Castillo/Tommy Vazquez/Raúl Sandoval Comedy,Music,Talk-Show
# nm0235465,nm0475430 nm1879108,nm1876156 tvEpisode Episode #14.191 Crime,Reality-TV
# \N \N tvEpisode Episode #8.3 Talk-Show
# nm0808527 \N video Lloyd Banks Feat. Lloyd: Any Girl Music,Short
# nm0898213,nm1539146 nm1272922 tvEpisode Episode #1.69 Romance
# \N \N tvEpisode Giada's Restaurant Favorites Family
# nm9981596 \N tvEpisode Gourmet Grilled Cheese Comedy,Reality-TV
# \N \N tvEpisode Episode #1.11 Game-Show
# nm0200519,nm0200520 \N short Congrès Short
# nm1019499,nm0527004,nm0657452,nm0526011 nm1006699,nm1212654,nm1213166,nm1213319,nm0539254,nm1142046,nm1272822,nm1213919,nm0848047 tvEpisode Episode #1.47 Comedy,Drama,Mystery
# nm0260619 \N tvEpisode Episode #37.68 Family,Game-Show,Reality-TV
# nm10905628 \N video New Comer hajirau hodo kanji sugiru G-Cup BODY Maki Kyoko Adult
# \N \N tvEpisode Episode dated 30 June 2002 Talk-Show
# \N \N tvEpisode Episode dated 5 November 2010 News,Talk-Show
# \N \N tvEpisode Episode #3.70 Talk-Show
# \N nm0475446 tvEpisode Episode dated 7 April 2000 Game-Show
# nm10132172 \N tvEpisode Pilot Animation
# \N \N tvEpisode For Esme, with Love Adult
# nm4647864 nm4647864 short Sapanta Documentary,Short
# \N \N tvEpisode Episode dated 30 November 2013 News
# nm0954698,nm8457691 nm7160298 tvEpisode Episode #1.1875 Animation,Family
# nm0491603 nm0463305,nm2179839 tvMovie Fisch zu viert Comedy
# nm8787258 \N tvSpecial Ashibo Na Ar Phire Drama
# \N \N tvEpisode Episode #10.18 Comedy
# nm0267399,nm0754763,nm0537354,nm0181884 nm0057007,nm0154499,nm0604356 tvEpisode Episode #1.41 Drama,Romance
# nm5421467 nm3759120 tvSpecial Just for Laughs: 15 Years of Gags Comedy
# \N nm3097292,nm3097698 short Perfect Drama,Short
# \N \N tvEpisode El lado bueno Family
# nm3888890 nm3888890 short Mutiny: Dc Comedy,Drama,Short
# nm3538522 \N tvEpisode Episode #10.3 Comedy,Game-Show
# \N nm0374325 tvEpisode Noches florentinas Comedy,Drama
# nm0696489 nm0112944,nm0170306,nm0247243,nm0329634,nm0334946,nm0369870,nm0416853,nm0426351,nm0428568,nm0452929,nm0470913,nm0580528,nm0630497,nm2154640,nm0810431,nm0935540 tvEpisode Will Ferrell & Chris Kattan Comedy,News,Talk-Show
# nm0471794 nm0718107,nm3664061,nm2080999,nm2103526,nm3498371 tvEpisode Partyabend Drama,Romance
# nm0481498 \N tvEpisode Episode #1.23 Comedy
# nm7482607 \N short If You Believe in Me Short
# nm4688549 nm4688549,nm4688051,nm4688019 tvEpisode Dejection and Rejuvenation Comedy
# nm4801087 nm9376064 tvEpisode Episode #1.37 Documentary
# nm3748167 \N short Sunset Strip Animation,Short
# nm2088032 nm2088032 short A Ressurreição de Lázaro Não Servirá Sci-Fi,Short
# \N \N videoGame Cliffhanger \N
# nm11262114 \N tvEpisode Episode #1.25 Drama
# nm4319023 nm1316903 short Champions Drama,Short
# nm1397919 \N tvEpisode Episode dated 26 April 2003 \N
# \N \N tvEpisode Episode dated 6 August 2010 News,Talk-Show
# nm1856805,nm4743757,nm3757983 nm3534328,nm9244142,nm0398970,nm4800367,nm1856805,nm6915755 tvEpisode Episode #2.3 Drama
# \N nm0693338 tvEpisode Episode #1.96 Music
# nm10155337 nm10155337 tvSeries Nightingale - Lonely Melodies Adventure
# nm10574875 nm5176456 movie How to Have an Out of Body Experience Documentary
# nm4371943 \N tvEpisode Episode #1.3 Drama,Family
# nm1196615 nm5883289,nm5883295,nm1196615 movie Aire de chacarera Documentary
# \N \N tvEpisode Episode dated 12 February 2008 Comedy,Drama,Romance
# nm0105826 \N tvSeries Wie Pech und Schwefel \N
# \N \N tvEpisode Episode #1.4372 News
# \N \N tvEpisode Clash on Cloud City Action,Adventure,Animation
# nm4025008 nm4025008 movie Aurora notte Comedy,Drama
# nm0348735,nm0290544 nm0650481,nm0733345 tvEpisode Episode #1.17 \N
# nm9955440 \N movie Naa Love Story Drama
# \N nm8921202 tvEpisode Pavlína Louzenská Talk-Show
# \N \N tvSpecial Prémios Bordalo 1994 \N
# nm0454437 nm0629456,nm0896000,nm0228947,nm0759168 tvEpisode A Place for Ponga Adventure,Family
# \N \N tvEpisode Das Geheimnis des Geiselnehmers Crime
# nm2767894 nm4164525,nm2736223,nm2323843,nm2726303,nm8890191,nm8890192 videoGame Horizon Zero Dawn Action,Adventure,Fantasy
# \N \N tvEpisode Ipswich Reality-TV
# nm0918301 nm8094041,nm0918301 tvEpisode Les Taupes rouges News
# \N \N tvEpisode Episode #10.34 News,Talk-Show
# \N \N tvEpisode Episode dated 2 April 2018 \N
# nm8238511 nm8238511 tvEpisode Applebloom and Pinkamena Action,Animation,Comedy
# nm0793062 nm0319213,nm1112464,nm2943462 tvEpisode Good Cop, Bad Cop Comedy,Crime,Drama
# \N nm0108702,nm2772986 tvEpisode Nathanael Greene History
# nm1066180 nm1017118 short Taken for Granted Short
# \N nm1202178,nm2610456 tvEpisode Episode #1.423 Drama
# \N \N tvEpisode Episode #1.4825 Drama,Romance
# nm1288551 nm6080465,nm1288551 movie Praseto Drama
# \N \N tvEpisode Episode dated 14 April 2005 Talk-Show
# nm1849415 nm1849415 short Berserker Drama,Short
# nm0215206 \N video Johnny Berlin Part 2: Notes from the Dumpster Comedy,Documentary
# nm2441372 nm2865463,nm2441203 tvEpisode Episode #1.1091 Drama
# \N \N tvEpisode Episode #1.4 Comedy,Romance
# nm2879083 nm2879083 movie Beto! The Bad Boy of Thompson Street Crime
# \N \N tvEpisode Episode dated 24 August 2021 News
# \N \N tvEpisode Episode #1.57 Drama
# nm1871870 nm1283753,nm1041838 tvEpisode Episode #15.91 Action,Comedy,Drama
# \N \N tvEpisode Episode #15.4 Reality-TV
# nm11053341 nm11580296,nm11580297,nm11054490,nm11053341 movie Contactus \N
# nm5674678 nm12797139,nm12797138,nm12797140 tvEpisode Episode #1.51 Drama
# \N \N tvEpisode Episode dated 16 May 2012 Talk-Show
# \N \N tvEpisode Keimo ja Kulkuri \N
# \N \N tvEpisode The Quest of Isis Family,Fantasy
# nm2318264,nm1754459 nm2494137,nm6015049,nm1699819,nm8626830,nm9516453,nm5723908 tvEpisode Kalbin Pesinde Comedy,Romance
# \N \N tvEpisode Terminator: Genisys Super Bowl Teaser Review Talk-Show
# \N \N tvEpisode Fantastic Beasts and Where to Find Them News
# \N \N tvEpisode Episode #1.4 Game-Show
# \N \N tvEpisode Episode #1.165 Comedy,Music,Talk-Show
# nm4552237 \N tvEpisode Episode #4.20 Game-Show
# nm1974852 \N tvEpisode Bluefin Beat Down Reality-TV
# nm0810026 nm0171837,nm0309420 tvEpisode Geoffrey Rush/Gwyneth Paltrow/Lady Gaga/Jason Byrne Comedy,Music,Talk-Show
# nm8805443,nm11508447 \N movie Alas de la Armada Documentary
# \N \N tvEpisode EHBO Comedy
# \N \N tvEpisode Denver Broncos vs. Oakland Raiders Sport
# \N \N tvEpisode Episode #1.51 Game-Show,Reality-TV
# nm1706412 \N tvEpisode The 12 Days of Redneck Christmas Documentary
# nm11673674 \N tvEpisode Episode #1.7 Drama
# nm1122444 nm0307639,nm1084211,nm0734570 tvEpisode Episode #1.82 Drama,Romance
# \N \N tvEpisode Episode #14.5 Comedy,Music,Talk-Show
# nm5061089,nm5061624 \N movie Werewolves Across America Documentary
# \N nm5676306 tvEpisode Giants: Part 2 News
# nm3159708 nm3159708,nm6386963 tvEpisode The Shaft Comedy
# nm1568433,nm0721405,nm0757739 nm3064446,nm3052538 tvEpisode Episode #5.109 Drama,Family
# \N nm7032708,nm11674113 tvEpisode Womb Envy Comedy
# nm3667746 \N movie What's in a Name Biography,Documentary
# nm5535968 nm5535968 tvEpisode Begins Fantasy
# \N \N tvEpisode Bay Area to the Big Island Reality-TV
# nm1807629 nm1277109 tvEpisode Redemption: Part 1 Crime,Drama,Mystery
# \N \N tvEpisode Episode #1.209 Drama
# \N \N tvEpisode Episode #4.13 Game-Show,Music
# nm0520317,nm5375487,nm8313105 nm0086104 tvEpisode Croire Drama
# \N \N tvEpisode Episode dated 27 March 2009 \N
# nm1130096 nm2591398 tvEpisode Episode #1.959 Comedy
# \N \N tvEpisode Der Bärenhäuter Adventure,Animation,Family
# \N nm0482921 tvEpisode Episode #1.118 Talk-Show
# \N \N tvEpisode Episode #1.8678 Drama,Romance
# nm1726784 \N video Erotic Massage Stories Adult
# nm0265289 nm0265289 short Jerry's Star Bout Comedy,Short
# nm0853028 nm0627454,nm0268196 movie Outlawed Guns Action,Drama,Western
# nm0641874 nm0641874 tvEpisode Episode #1.22 Talk-Show
# nm0051678 nm1065581,nm1065952 tvEpisode Episode #9.97 Comedy,Drama,Music
# nm2140264 \N tvEpisode Episode #1.4 Documentary
# nm0671543 nm5967570,nm0671543 tvEpisode Take Care of It Comedy
# \N \N tvEpisode Busty blond bank manager held hostage by a sadistic bank robber Adult
# nm0339567 nm0723665 tvEpisode Episode #1.6 Drama
# \N \N tvEpisode Episode #3.20 Comedy,Game-Show,Reality-TV
# nm0565214 \N tvEpisode Episode #12.212 Game-Show
# \N \N tvEpisode GEILER als deine Ehefotze Adult
# nm0841589 nm2208201,nm0841589 tvEpisode Hayseed and Company: Part 2 - A Hard Bargain Family,Fantasy
# \N \N tvEpisode Heiße deutsche Sekretärin in einem deutschen Büro vom Chef genagelt Adult
# nm1334970,nm1203199 nm1340699,nm1203199 tvEpisode Episode #3.33 Drama
# \N \N tvEpisode Episode #9.25 Sport
# nm9026235,nm11058890 nm9026235,nm11058890 short I Love You, John Smith Romance,Short
# \N \N tvEpisode Boba: A Distraction Story? Comedy
# \N \N tvEpisode The Yorkshire Ripper Pt. 2 - Peter Sutcliffe Crime,Documentary
# nm3512127 nm3512127 short Nancy Boy Romance,Short
# \N \N tvEpisode Spring Cleaning News,Talk-Show
# nm12113094 nm12113094 movie Madurai Ponnu Chennai Paiyan Drama
# nm1676117 \N tvEpisode Episode #2.2 Documentary
# nm0188493 \N tvEpisode Boer War Biography,Documentary
# nm8222944,nm0151754 nm0795166,nm8581439,nm1287705,nm1967802,nm9030108,nm8581441 videoGame Watch Dogs Action,Crime,Drama
# nm7340687 nm8042385 tvEpisode Episode #1.48 Comedy
# \N nm0004980,nm3605915 tvEpisode Episode #2.11 Talk-Show
# \N nm0278696,nm0654162 tvEpisode Basil's Book Launch Comedy,Short
# \N \N video Women Seeking Women 135 Adult,Romance
# \N \N tvEpisode Episode dated 5 April 2016 Sport,Talk-Show
# nm6030944 nm5442688,nm10218346 tvEpisode Office romance Comedy
# \N \N tvEpisode Episode #1.1261 Drama,Romance
# nm6107976 nm6107976 short Summer Nights Drama,Romance,Short
# \N \N tvEpisode Zhyon Models Dancing in Latex Talk-Show
# \N \N tvEpisode My Lovely Lady Adult
# nm0367538 nm0000175,nm1590991,nm1636629,nm2238720,nm4000822 tvEpisode William Crime,Drama,Fantasy
# nm0623001,nm2594268 nm2594268,nm1942006,nm0623001 tvEpisode Episode #2.2 Comedy
# nm0602600,nm0134018 nm0889768,nm0840841,nm0704138,nm1583648 tvEpisode Una dura verdad Adventure,Drama,Family
# nm0165965 nm0153546,nm0326089,nm0267334,nm0472849 tvEpisode Murder Cartel Adventure,Crime
# nm0757877 nm0106039,nm0721201 tvEpisode Episode #1.149 Crime,Drama,Mystery
# nm1317983 nm0926448 tvEpisode Love on the Rocks Drama
# \N nm6513693 tvEpisode Millennial Mansion Reality-TV
# nm10052694 \N video FORD: The Beauty of Change Commercial Short
# \N \N tvEpisode Snoopy neighbor girl in trouble Adult
# \N \N tvEpisode Episode #1.2324 News,Talk-Show
# nm4371943,nm3515307,nm3771559,nm1667633,nm8408311,nm3260130 nm3540552,nm6176600,nm6421767,nm8474319,nm1939626,nm4609476,nm2407031,nm10585548,nm12139501 tvEpisode Episode #1.692 Drama,Family
# \N nm6601539,nm6601540 tvEpisode Drivers, Dive-ins, and Dykes Comedy
# \N \N tvEpisode De toekomst is nu Drama,Family
# \N \N tvEpisode Kaputis Drama
# nm0093505,nm1266342,nm1366190,nm1888052 nm2336044,nm1046369,nm1325876,nm1324213 tvEpisode Episode #1.96 Romance
# nm1190799 nm5626895 tvMovie Meine Nachbarn mit dem dicken Hund Comedy,Drama
# nm0222845 \N video Booty Quake 4 Adult
# \N \N tvEpisode Happily Ever After? Reality-TV
# \N \N tvEpisode Episode #1.70 Fantasy
# nm0000399 nm0671856,nm0235123,nm0647833,nm5616730,nm1964043 tvEpisode Episode #1.9 Crime,Drama,Thriller
# nm0134018 nm0028070,nm0523545 tvEpisode Quiero pedirte algo Mamá Crime,Drama,Thriller
# \N \N tvEpisode Episode #2.16 Reality-TV
# \N \N tvEpisode Jay Leno's Extreme Roadsters Documentary,History

# %%
movie_user_likes = "Blacksmith Scene"

#create count matrix from this new combined column
cv = CountVectorizer()

count_matrix = cv.fit_transform(IMDB_data["combined_features"])

#Compute the Cosine Similarity based on the count_matrix
cosine_sim = cosine_similarity(count_matrix)

# %%
### use helper fuctions
movie_index = get_index_from_title(movie_user_likes)

similar_movies = list(enumerate(cosine_sim[movie_index]))

# %%
#Get a list of similar movies in descensing order of similarity score
sorted_similar_movies = sorted(similar_movies,key=lambda x:x[1],reverse=True)

##Print titles of first 50 movies
i=0
for movie in sorted_similar_movies:
    print get_title_from_index(movie[0])
    i=+1
    if i>25:
        break
# Out:
#   File "<ipython-input-38-7de0a13a276c>", line 7
#     print get_title_from_index(movie[0])
#           ^
# SyntaxError: invalid syntax
