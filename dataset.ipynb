# %% [markdown]
# # Scraping Data using rapid-API

# %% [markdown]
# Downloadable data: https://www.imdb.com/interfaces/
#
# API profile registration: https://imdb-api.com/api/#Search-header
#
# All the urls: https://imdb-api.com/api/#Search-header

# %%
# Import data wranglers

import pandas as pd # data frame
import requests # gets the messy data for you
import json # much farmiliar with python syntax and structure
from getpass import getpass # if you want to hide your key on your scripts

# %%
def Movies():
 
    url = "https://imdb-api.com/en/API/MostPopularMovies/k_x3cxd26n" # dont forget to add your own API key

    headers = {
            'x-rapidapi-host': "imdb-api1.p.rapidapi.com",
            'x-rapidapi-key': str(getpass("Please enter an api-key:\n"))  # You can remove 'getpass' and just add your api as a str
            }

    response = requests.get(url, headers=headers) # geting the data using request library
    
    movie_list = response.json() # json file is more readable, which recognise it as a dictionary
    
    movies_data = movie_list['items'] # "'items' is the key to all those movie data"
     
    df = pd.DataFrame(movies_data) # yiu can play around with loobs here if you want to practice both pandas and loops
    
    return df

# %%
Movies()
# Out:
# Please enter an api-key:
# ········
#             id rank rankUpDown                                      title  \
# 0    tt1160419    1         +1                                       Dune
# 1    tt9376612    2         +1  Shang-Chi and the Legend of the Ten Rings
# 2    tt6264654    3         +8                                   Free Guy
# 3    tt1924245    4         +4                                  Cry Macho
# 4    tt3811906    5         -4                                  Malignant
# ..         ...  ...        ...                                        ...
# 95   tt0332379   96        -19                             School of Rock
# 96  tt10272386   97         -1                                 The Father
# 97   tt6751668   98         +9                                   Parasite
# 98   tt6654210   99        +14                                   Infinite
# 99   tt0113118  100      1,095                                     Friday
#
#                                            fullTitle  year  \
# 0                                        Dune (2021)  2021
# 1   Shang-Chi and the Legend of the Ten Rings (2021)  2021
# 2                                    Free Guy (2021)  2021
# 3                                   Cry Macho (2021)  2021
# 4                                   Malignant (2021)  2021
# ..                                               ...   ...
# 95                             School of Rock (2003)  2003
# 96                                 The Father (2020)  2020
# 97                                   Parasite (2019)  2019
# 98                                   Infinite (2021)  2021
# 99                                     Friday (1995)  1995
#
#                                                 image  \
# 0   https://m.media-amazon.com/images/M/MV5BN2FjNm...
# 1   https://m.media-amazon.com/images/M/MV5BNTliYj...
# 2   https://m.media-amazon.com/images/M/MV5BOTY2Nz...
# 3   https://m.media-amazon.com/images/M/MV5BOGQ5OT...
# 4   https://m.media-amazon.com/images/M/MV5BYTc0NW...
# ..                                                ...
# 95  https://m.media-amazon.com/images/M/MV5BMjEwOT...
# 96  https://m.media-amazon.com/images/M/MV5BZGJhNW...
# 97  https://m.media-amazon.com/images/M/MV5BYWZjMj...
# 98  https://m.media-amazon.com/images/M/MV5BZTU5Mm...
# 99  https://m.media-amazon.com/images/M/MV5BYmEwNj...
#
#                                                  crew imDbRating  \
# 0   Denis Villeneuve (dir.), Timothée Chalamet, Re...        8.4
# 1   Destin Daniel Cretton (dir.), Simu Liu, Awkwafina        7.9
# 2       Shawn Levy (dir.), Ryan Reynolds, Jodie Comer        7.4
# 3   Clint Eastwood (dir.), Clint Eastwood, Dwight ...        5.8
# 4   James Wan (dir.), Annabelle Wallis, Maddie Hasson        6.3
# ..                                                ...        ...
# 95   Richard Linklater (dir.), Jack Black, Mike White        7.1
# 96  Florian Zeller (dir.), Anthony Hopkins, Olivia...        8.3
# 97    Bong Joon Ho (dir.), Kang-ho Song, Sun-kyun Lee        8.6
# 98  Antoine Fuqua (dir.), Mark Wahlberg, Chiwetel ...        5.5
# 99        F. Gary Gray (dir.), Ice Cube, Chris Tucker        7.3
#
#    imDbRatingCount
# 0            51666
# 1            93117
# 2            86722
# 3             9068
# 4            41746
# ..             ...
# 95          290337
# 96           97452
# 97          661550
# 98           28496
# 99          105447
#
# [100 rows x 10 columns]
